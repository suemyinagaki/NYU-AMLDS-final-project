# %% [markdown]
# ## Independend Unbiased Space Saving (I-USS) and Coordinated Unbiased Space Saving (C-USS)
#
# Final Project
#
# Algorithmic Machine Learning for Data Science, Fall 2023
#
#
# Suemy Inagaki (si2324)
# Felipe de Oliveira (fd2264)

# %%
# !pip install surpyval
import random
from surpyval import Weibull
import matplotlib.pyplot as plt
import numpy as np
import time

# %%
def hash_kwise_kv(keys,use_seed= False, seed = 12345, dimension_num=1, k_wise=4, PRIME=2147483587):
    #receives a streaming os keys and returns a streaming of hashes from 0 to 1
    if(use_seed):
      np.random.seed(seed)
    hash_parameters = np.random.randint(1, PRIME, (dimension_num, k_wise))
    hash_kwise = 0
    for exp in range(k_wise):
        hash_kwise += np.dot(np.transpose(np.array([keys])**exp), np.array([np.transpose(hash_parameters[:, exp])]))
    hash_kwise = np.mod(hash_kwise, PRIME)/PRIME
    hashes = hash_kwise.reshape(hash_kwise.shape[0],)
    return hashes

def unbiased_space_saving(streaming, n, m):
  sketch = {}
  x_min = streaming[0]
  N_min = 1
  for i in range(n):
    key = streaming[i]
    if(key in sketch.keys()):
      sketch[key] += 1
    else:
      if(len(sketch) <= m):
        sketch[key] = 1
      else:
        a = random.uniform(0, 1)
        p = 1/(N_min + 1)
        if (a < p):
          sketch[x_min] += 1
          N_min = sketch[x_min]
          sketch[key] = sketch[x_min]
          del sketch[x_min]
          x_min = key
  return sketch



def unbiased_space_saving_coordinated(streaming, n, m):
  sketch = {}
  x_min = streaming[0]
  N_min = 1
  hashes = hash_kwise_kv(streaming, use_seed = True)
  for i in range(n):
    key = streaming[i]
    if(key in sketch.keys()):
      sketch[key] += 1
    else:
      if(len(sketch) <= m):
        sketch[key] = 1
      else:
        a = hashes[i]
        p = 1/(N_min + 1)
        if (a < p):
          sketch[x_min] += 1
          N_min = sketch[x_min]
          sketch[key] = sketch[x_min]
          del sketch[x_min]
          x_min = key
  return sketch

def Priority_Sampling_Chris(aggregated_streaming,m):
  import math
  keys = list(aggregated_streaming.keys())
  values = list(aggregated_streaming.values())
  hashes = hash_kwise_kv(keys)
  norm_2 = np.sum(np.array(values)**2)
  k_v = {}
  #pick the m smallest ranks
  Ranks = [hashes[i]/(values[i]**2) for i in range(len(keys))]

  if(len(keys)<m+1):
    Threshold = math.inf
    index_to_store = range(len(keys))
  else:
    index_to_store = np.argsort(Ranks)[0:m+1]
    Threshold = Ranks[index_to_store[m]]


  for i in index_to_store:
      k_v[keys[i]] = values[i]
  return {"kv":k_v, "threshold" :Threshold }


def threshold_sampling_Chris(aggregated_streaming, m):
  keys = list(aggregated_streaming.keys())
  values = list(aggregated_streaming.values())
  hashes = hash_kwise_kv(keys)
  norm_2 = np.sum(np.array(values)**2)
  k_v = {}
  for i in range(len(keys)):
    threshold = m*values[i]**2/norm_2
    if(hashes[i]<= threshold):
      k_v[keys[i]] = values[i]
  return {"kv":k_v, "threshold" :m/norm_2 }

def inner_product_from_threshold(sketch1, sketch2, return_inner_vector=False):
  key_intersection = list(set(sketch1["kv"].keys()) & set(sketch2["kv"].keys()))
  inner_product_estimate = {}
  for key in key_intersection:
    probability = np.min([1,sketch1["threshold"]*sketch1["kv"][key]**2, sketch2["threshold"]*sketch2["kv"][key]**2 ])
    inner_product_estimate[key]  = sketch1["kv"][key] *sketch2["kv"][key] / probability
  if(return_inner_vector):
    return  np.sum(list(inner_product_estimate.values())), inner_product_estimate
  else:
    return np.sum(list(inner_product_estimate.values()))

def agms(streaming1, streaming2, number_estimates, k_wise =4):
  #receives a pair of streamings and returns an estimate of the inner product between both
  PRIME = 2147483587
  hash_parameters = np.random.randint(1, PRIME, (number_estimates, k_wise))
  hash_kwise = 0
  for exp in range(k_wise):
      hash_kwise += np.dot(np.transpose(np.array([streaming1])**exp), np.array([np.transpose(hash_parameters[:, exp])]))
  hash_kwise = 2*(np.mod(np.mod(hash_kwise, PRIME),2)-1/2) # putting in +-1 instead of in Zp
  estimates1 = np.sum(hash_kwise,axis=0)

  hash_kwise = 0
  for exp in range(k_wise):
      hash_kwise += np.dot(np.transpose(np.array([streaming2])**exp), np.array([np.transpose(hash_parameters[:, exp])]))
  hash_kwise = 2*(np.mod(np.mod(hash_kwise, PRIME),2)-1/2) # putting in +-1 instead of in Zp
  estimates2 = np.sum(hash_kwise,axis=0)

  inner_product_estimate = np.mean([estimates1[i]*estimates2[i] for i in range(number_estimates)]  )

  return inner_product_estimate


def fast_agms(streaming1, streaming2, number_estimates, k_wise =4):
  #receives a pair of streamings and returns an estimate of the inner product between both
  PRIME = 2147483587
  hash_4_parameters = np.random.randint(1, PRIME, (1, k_wise))
  hash_2_parameters = np.random.randint(1, PRIME, (1, 2))
  hash_kwise_2 = 0
  hash_kwise_4 = 0
  sketch_1 = np.zeros(number_estimates)
  sketch_2 = np.zeros(number_estimates)

  #Hash for the position of the sketch
  for exp in range(2):
      hash_kwise_2 += np.dot(np.transpose(np.array([streaming1])**exp), np.array([np.transpose(hash_2_parameters[:, exp])]))
  hash_kwise_2 = np.mod(np.mod(hash_kwise_2, PRIME),number_estimates)# putting in 0 to m-1
  hash_kwise_2 = hash_kwise_2.reshape(hash_kwise_2.shape[0],)

  #Hash for +/- 1
  for exp in range(k_wise):
      hash_kwise_4 += np.dot(np.transpose(np.array([streaming1])**exp), np.array([np.transpose(hash_4_parameters[:, exp])]))
  hash_kwise_4 = 2*(np.mod(np.mod(hash_kwise_4, PRIME),2)-1/2) # putting in +-1 instead of in Zp
  hash_kwise_4 = hash_kwise_4.reshape(hash_kwise_4.shape[0],)


  for i in range(len(streaming1)):
    sketch_1[hash_kwise_2[i]] += hash_kwise_4[i]

  hash_kwise_2 = 0
  hash_kwise_4 = 0

  #Hash for the position of the sketch
  for exp in range(2):
      hash_kwise_2 += np.dot(np.transpose(np.array([streaming2])**exp), np.array([np.transpose(hash_2_parameters[:, exp])]))
  hash_kwise_2 = np.mod(np.mod(hash_kwise_2, PRIME),number_estimates)# putting in 0 to m-1
  hash_kwise_2 = hash_kwise_2.reshape(hash_kwise_2.shape[0],)

  #Hash for +/- 1
  for exp in range(k_wise):
      hash_kwise_4 += np.dot(np.transpose(np.array([streaming2])**exp), np.array([np.transpose(hash_4_parameters[:, exp])]))
  hash_kwise_4 = 2*(np.mod(np.mod(hash_kwise_4, PRIME),2)-1/2) # putting in +-1 instead of in Zp
  hash_kwise_4 = hash_kwise_4.reshape(hash_kwise_4.shape[0],)


  for i in range(len(streaming2)):
    sketch_2[hash_kwise_2[i]] += hash_kwise_4[i]

  inner_product_estimate = np.sum([sketch_2[i]*sketch_1[i] for i in range(number_estimates)]  )

  return inner_product_estimate

def get_inner_vector(d1, d2):
  keys = [k for k in d1.keys() if k in d2.keys()]
  v_s = {}
  keys.sort()
  for k in keys:
    v_s[k] = d1[k]*d2[k]
  return v_s

def get_answer(streaming, n):
  keys, frequencies = np.unique(streaming, return_counts=True)
  a = zip(keys, frequencies)
  di = dict(a)
  return di

def fill_inner_vector(inner_vector_sketch, answer):
  keys = [i for i in answer.keys() if i not in inner_vector_sketch.keys()]
  for k in keys:
    inner_vector_sketch[k] = 0

  sorted_result = dict(sorted(inner_vector_sketch.items(),  key=lambda x:x[0]))
  return sorted_result

def get_inner_product_from_estimates(estimate1, estimate2):
  sum = 0
  for i in range(len(estimate1)):
    sum += estimate1[i]*estimate2[i]
  return sum/len(estimate1)


def calculate_inner_product(d):
  values = list(d.values())
  sum = 0
  for v in values:
    sum += v
  return sum

def generate_weibull(alpha, beta, n):
  rng = np.random.default_rng()
  streaming = rng.weibull(beta, n)
  streaming = [round(alpha*i) for i in streaming]
  return streaming

def generate_truncated_weibull(alpha, beta, a, b, n):
  model = Weibull.from_params((alpha, beta))
  streaming = model.random(n, a=a, b=b)
  streaming = [round(i) for i in streaming]
  return streaming

def generate_zipf(alpha, n):
  s = np.random.default_rng().zipf(alpha, size=n)
  return s

def generate_geometric(p, n):
  streaming = np.random.geometric(p, n)
  return streaming

def get_streamings(n):
  data = []
  # Weibull:
  alpha = 500000
  betas = [0.32, 0.15]
  a, b = 1, 1000
  for beta in betas:
    s1 = generate_weibull(alpha, beta, n)
    s2 = generate_weibull(alpha, beta, n)
    o = {
       "params": {
        "alpha": alpha,
        "beta": beta,
        "generator": "weibull"
      },
       "s1": s1,
       "s2": s2
    }
    data.append(o)
    s1 = generate_truncated_weibull(alpha, beta, a, b, n)
    s2 = generate_truncated_weibull(alpha, beta, a, b, n)
    o = {
       "params": {
        "alpha": alpha,
        "beta": beta,
        "a": a,
        "b": b,
        "generator": "truncated_weibull"
      },
       "s1": s1,
       "s2": s2
    }
    data.append(o)
  s1 = generate_geometric(0.03, n)
  s2 = generate_geometric(0.03, n)
  o = {
      "params": {
      "p": 0.03,
      "generator": "geometric"
    },
      "s1": s1,
      "s2": s2
  }
  data.append(o)
  alphas = [1.1, 2, 3, 4]
  for aa in alphas:
    s1 = generate_zipf(aa, n)
    s2 = generate_zipf(aa, n)
    o = {
        "params": {
        "alpha": aa,
        "generator": "zipfian"
      },
        "s1": s1,
        "s2": s2
    }
    data.append(o)
  return data

# %%
m = [100, 200, 300]

final_results_unbiased = []
final_results_unbiased_coordinated = []
final_results_agms = []
final_results_threshold = []
final_results_priority = []

q = 100
n = 400000
data = get_streamings(n)
for t in range(q):
  iteration_result_unbiased = {}
  iteration_result_unbiased_coordinated = {}
  iteration_result_agms = {}
  iteration_result_threshold = {}
  iteration_result_priority = {}
  print(t)
  for d in data:
    streaming1 = d.get("s1")
    streaming2 = d.get("s1")
    for size in m:
      t1 = time.time()
      sketch1 = unbiased_space_saving(streaming1, n, size)
      sketch2 = unbiased_space_saving(streaming2, n, size)
      t2 = time.time()
      answer1 = get_answer(streaming1, n)
      answer2 = get_answer(streaming2, n)
      v = get_inner_vector(sketch1, sketch2)
      v_ans = get_inner_vector(answer1, answer1)
      ans = calculate_inner_product(v_ans)
      est = calculate_inner_product(v)

      params = list(d.get("params").values())
      params.append(size)
      key = ""
      for p in params:
        key+=f"{p}-"
      key = key[:len(key)-1]
      iteration_result_unbiased[key] = {
          "relative_error": abs(ans - est)/ans,
          "absolute_error": abs(ans - est),
          "duration": t2 - t1
      }

      t1 = time.time()
      est = fast_agms(streaming1, streaming2, size, 4)
      t2 = time.time()
      iteration_result_agms[key] = {
          "relative_error": abs(ans - est)/ans,
          "absolute_error": abs(ans - est),
          "duration": t2 - t1
      }

      t1 = time.time()
      sketch11 = unbiased_space_saving_coordinated(streaming1, n, size)
      sketch22 = unbiased_space_saving_coordinated(streaming2, n, size)
      t2 = time.time()
      v = get_inner_vector(sketch11, sketch22)
      v_ans = get_inner_vector(answer1, answer1)
      ans = calculate_inner_product(v_ans)
      est = calculate_inner_product(v)

      iteration_result_unbiased_coordinated[key] = {
          "relative_error": abs(ans - est)/ans,
          "absolute_error": abs(ans - est),
          "duration": t2 - t1
      }

      t1 = time.time()
      ag1 = get_answer(streaming1, n)
      ag2 = get_answer(streaming2, n)
      sketch111 = threshold_sampling_Chris(ag1, size)
      sketch222 = threshold_sampling_Chris(ag2, size)
      t2 = time.time()
      est = inner_product_from_threshold(sketch111, sketch222)

      iteration_result_threshold[key] = {
          "relative_error": abs(ans - est)/ans,
          "absolute_error": abs(ans - est),
          "duration": t2 - t1
      }

      t1 = time.time()
      sketch1111 = Priority_Sampling_Chris(ag1, size)
      sketch2222 = Priority_Sampling_Chris(ag2, size)
      t2 = time.time()
      est = inner_product_from_threshold(sketch1111, sketch2222)

      iteration_result_priority[key] = {
          "relative_error": abs(ans - est)/ans,
          "absolute_error": abs(ans - est),
          "duration": t2 - t1
      }
  final_results_unbiased.append(iteration_result_unbiased)
  final_results_unbiased_coordinated.append(iteration_result_unbiased_coordinated)
  final_results_agms.append(iteration_result_agms)
  final_results_threshold.append(iteration_result_threshold)
  final_results_priority.append(iteration_result_priority)

# %%
keys = list(final_results_unbiased[0].keys())
print("Unbiased Space Saving")
mean_final_results_unbiased = []
for k in keys:
  absolute_error = 0
  relative_error = 0
  duration = 0
  for result in final_results_unbiased:
      absolute_error += result.get(k).get("absolute_error")
      relative_error += result.get(k).get("relative_error")
      duration += result.get(k).get("duration")
  mean_final_results_unbiased.append([k, absolute_error/q, relative_error/q, duration/q])

  print(f"distribution: {k}")
  print(f"{q} iteractions")
  print(f"Mean Absolute Error: {absolute_error/q}")
  print(f"Mean Relative Error: {relative_error/q}")
  print(f"Mean Duration: {round(duration/q, 2)} seconds")
  print("-------------------------------------------")
# Out:
# Unbiased Space Saving
# distribution: 500000-0.32-weibull-100
# 100 iteractions
# Mean Absolute Error: 11848363.0
# Mean Relative Error: 0.3351454904936491
# Mean Duration: 0.3 seconds
# -------------------------------------------
# distribution: 500000-0.32-weibull-200
# 100 iteractions
# Mean Absolute Error: 6425203.0
# Mean Relative Error: 0.18174475334324802
# Mean Duration: 0.3 seconds
# -------------------------------------------
# distribution: 500000-0.32-weibull-300
# 100 iteractions
# Mean Absolute Error: 6193519.0
# Mean Relative Error: 0.1751912870273082
# Mean Duration: 0.31 seconds
# -------------------------------------------
# distribution: 500000-0.32-1-1000-truncated_weibull-100
# 100 iteractions
# Mean Absolute Error: 337511949.0
# Mean Relative Error: 0.5365029791663072
# Mean Duration: 0.27 seconds
# -------------------------------------------
# distribution: 500000-0.32-1-1000-truncated_weibull-200
# 100 iteractions
# Mean Absolute Error: 216068625.0
# Mean Relative Error: 0.3434588356362688
# Mean Duration: 0.26 seconds
# -------------------------------------------
# distribution: 500000-0.32-1-1000-truncated_weibull-300
# 100 iteractions
# Mean Absolute Error: 180305875.0
# Mean Relative Error: 0.2866110055815763
# Mean Duration: 0.22 seconds
# -------------------------------------------
# distribution: 500000-0.15-weibull-100
# 100 iteractions
# Mean Absolute Error: 32886987.0
# Mean Relative Error: 0.014137689439449602
# Mean Duration: 0.29 seconds
# -------------------------------------------
# distribution: 500000-0.15-weibull-200
# 100 iteractions
# Mean Absolute Error: 17880140.75
# Mean Relative Error: 0.007686440751083327
# Mean Duration: 0.28 seconds
# -------------------------------------------
# distribution: 500000-0.15-weibull-300
# 100 iteractions
# Mean Absolute Error: 17005540.0
# Mean Relative Error: 0.007310461224986578
# Mean Duration: 0.28 seconds
# -------------------------------------------
# distribution: 500000-0.15-1-1000-truncated_weibull-100
# 100 iteractions
# Mean Absolute Error: 203355703.0
# Mean Relative Error: 0.12772558984585858
# Mean Duration: 0.24 seconds
# -------------------------------------------
# distribution: 500000-0.15-1-1000-truncated_weibull-200
# 100 iteractions
# Mean Absolute Error: 133043568.2
# Mean Relative Error: 0.08356327348017724
# Mean Duration: 0.23 seconds
# -------------------------------------------
# distribution: 500000-0.15-1-1000-truncated_weibull-300
# 100 iteractions
# Mean Absolute Error: 111056385.16
# Mean Relative Error: 0.06975335381034206
# Mean Duration: 0.2 seconds
# -------------------------------------------
# distribution: 0.03-geometric-100
# 100 iteractions
# Mean Absolute Error: 136323095.29
# Mean Relative Error: 0.056062822912595005
# Mean Duration: 0.25 seconds
# -------------------------------------------
# distribution: 0.03-geometric-200
# 100 iteractions
# Mean Absolute Error: 86903380.14
# Mean Relative Error: 0.03573898319232293
# Mean Duration: 0.23 seconds
# -------------------------------------------
# distribution: 0.03-geometric-300
# 100 iteractions
# Mean Absolute Error: 86451545.73
# Mean Relative Error: 0.0355531664570165
# Mean Duration: 0.22 seconds
# -------------------------------------------
# distribution: 1.1-zipfian-100
# 100 iteractions
# Mean Absolute Error: 91894430.24
# Mean Relative Error: 0.04342198951909009
# Mean Duration: 0.35 seconds
# -------------------------------------------
# distribution: 1.1-zipfian-200
# 100 iteractions
# Mean Absolute Error: 57250037.0
# Mean Relative Error: 0.02705180825528908
# Mean Duration: 0.34 seconds
# -------------------------------------------
# distribution: 1.1-zipfian-300
# 100 iteractions
# Mean Absolute Error: 24351744.0
# Mean Relative Error: 0.011506694910430994
# Mean Duration: 0.35 seconds
# -------------------------------------------
# distribution: 2-zipfian-100
# 100 iteractions
# Mean Absolute Error: 1652521.44
# Mean Relative Error: 2.5769534739156055e-05
# Mean Duration: 0.22 seconds
# -------------------------------------------
# distribution: 2-zipfian-200
# 100 iteractions
# Mean Absolute Error: 1540680.95
# Mean Relative Error: 2.4025486327718088e-05
# Mean Duration: 0.24 seconds
# -------------------------------------------
# distribution: 2-zipfian-300
# 100 iteractions
# Mean Absolute Error: 1496121.86
# Mean Relative Error: 2.3330628766475062e-05
# Mean Duration: 0.22 seconds
# -------------------------------------------
# distribution: 3-zipfian-100
# 100 iteractions
# Mean Absolute Error: 0.0
# Mean Relative Error: 0.0
# Mean Duration: 0.22 seconds
# -------------------------------------------
# distribution: 3-zipfian-200
# 100 iteractions
# Mean Absolute Error: 0.0
# Mean Relative Error: 0.0
# Mean Duration: 0.22 seconds
# -------------------------------------------
# distribution: 3-zipfian-300
# 100 iteractions
# Mean Absolute Error: 0.0
# Mean Relative Error: 0.0
# Mean Duration: 0.21 seconds
# -------------------------------------------
# distribution: 4-zipfian-100
# 100 iteractions
# Mean Absolute Error: 0.0
# Mean Relative Error: 0.0
# Mean Duration: 0.21 seconds
# -------------------------------------------
# distribution: 4-zipfian-200
# 100 iteractions
# Mean Absolute Error: 0.0
# Mean Relative Error: 0.0
# Mean Duration: 0.22 seconds
# -------------------------------------------
# distribution: 4-zipfian-300
# 100 iteractions
# Mean Absolute Error: 0.0
# Mean Relative Error: 0.0
# Mean Duration: 0.22 seconds
# -------------------------------------------

# %%
keys = list(final_results_unbiased_coordinated[0].keys())
print("Unbiased Space Saving Coordinated")
mean_final_results_unbiased_coordinated = []
for k in keys:
  absolute_error = 0
  relative_error = 0
  duration = 0
  for result in final_results_unbiased_coordinated:
      absolute_error += result.get(k).get("absolute_error")
      relative_error += result.get(k).get("relative_error")
      duration += result.get(k).get("duration")
  mean_final_results_unbiased_coordinated.append([k, absolute_error/q, relative_error/q, duration/q])

  print(f"distribution: {k}")
  print(f"{q} iteractions")
  print(f"Mean Absolute Error: {absolute_error/q}")
  print(f"Mean Relative Error: {relative_error/q}")
  print(f"Mean Duration: {round(duration/q, 2)} seconds")
  print("-------------------------------------------")
# Out:
# Unbiased Space Saving Coordinated
# distribution: 500000-0.32-weibull-100
# 100 iteractions
# Mean Absolute Error: 11848363.0
# Mean Relative Error: 0.3351454904936491
# Mean Duration: 0.44 seconds
# -------------------------------------------
# distribution: 500000-0.32-weibull-200
# 100 iteractions
# Mean Absolute Error: 6425203.0
# Mean Relative Error: 0.18174475334324802
# Mean Duration: 0.43 seconds
# -------------------------------------------
# distribution: 500000-0.32-weibull-300
# 100 iteractions
# Mean Absolute Error: 6186009.76
# Mean Relative Error: 0.17497887895684022
# Mean Duration: 0.45 seconds
# -------------------------------------------
# distribution: 500000-0.32-1-1000-truncated_weibull-100
# 100 iteractions
# Mean Absolute Error: 337511949.0
# Mean Relative Error: 0.5365029791663072
# Mean Duration: 0.41 seconds
# -------------------------------------------
# distribution: 500000-0.32-1-1000-truncated_weibull-200
# 100 iteractions
# Mean Absolute Error: 216068625.0
# Mean Relative Error: 0.3434588356362688
# Mean Duration: 0.38 seconds
# -------------------------------------------
# distribution: 500000-0.32-1-1000-truncated_weibull-300
# 100 iteractions
# Mean Absolute Error: 180327436.96
# Mean Relative Error: 0.28664528008892615
# Mean Duration: 0.39 seconds
# -------------------------------------------
# distribution: 500000-0.15-weibull-100
# 100 iteractions
# Mean Absolute Error: 32886987.0
# Mean Relative Error: 0.014137689439449602
# Mean Duration: 0.42 seconds
# -------------------------------------------
# distribution: 500000-0.15-weibull-200
# 100 iteractions
# Mean Absolute Error: 17887280.0
# Mean Relative Error: 0.007689509822121382
# Mean Duration: 0.43 seconds
# -------------------------------------------
# distribution: 500000-0.15-weibull-300
# 100 iteractions
# Mean Absolute Error: 17005540.0
# Mean Relative Error: 0.007310461224986578
# Mean Duration: 0.43 seconds
# -------------------------------------------
# distribution: 500000-0.15-1-1000-truncated_weibull-100
# 100 iteractions
# Mean Absolute Error: 203355703.0
# Mean Relative Error: 0.12772558984585858
# Mean Duration: 0.38 seconds
# -------------------------------------------
# distribution: 500000-0.15-1-1000-truncated_weibull-200
# 100 iteractions
# Mean Absolute Error: 133056265.0
# Mean Relative Error: 0.08357124820744198
# Mean Duration: 0.38 seconds
# -------------------------------------------
# distribution: 500000-0.15-1-1000-truncated_weibull-300
# 100 iteractions
# Mean Absolute Error: 111061156.78
# Mean Relative Error: 0.0697563508149504
# Mean Duration: 0.38 seconds
# -------------------------------------------
# distribution: 0.03-geometric-100
# 100 iteractions
# Mean Absolute Error: 137541062.32
# Mean Relative Error: 0.05656371140673468
# Mean Duration: 0.27 seconds
# -------------------------------------------
# distribution: 0.03-geometric-200
# 100 iteractions
# Mean Absolute Error: 117363001.58
# Mean Relative Error: 0.048265491331994405
# Mean Duration: 0.26 seconds
# -------------------------------------------
# distribution: 0.03-geometric-300
# 100 iteractions
# Mean Absolute Error: 110398008.89
# Mean Relative Error: 0.045401140644120666
# Mean Duration: 0.27 seconds
# -------------------------------------------
# distribution: 1.1-zipfian-100
# 100 iteractions
# Mean Absolute Error: 91903190.0
# Mean Relative Error: 0.0434261286840636
# Mean Duration: 0.32 seconds
# -------------------------------------------
# distribution: 1.1-zipfian-200
# 100 iteractions
# Mean Absolute Error: 57250037.0
# Mean Relative Error: 0.02705180825528908
# Mean Duration: 0.3 seconds
# -------------------------------------------
# distribution: 1.1-zipfian-300
# 100 iteractions
# Mean Absolute Error: 24351744.0
# Mean Relative Error: 0.011506694910430994
# Mean Duration: 0.32 seconds
# -------------------------------------------
# distribution: 2-zipfian-100
# 100 iteractions
# Mean Absolute Error: 1667703.62
# Mean Relative Error: 2.6006286714323244e-05
# Mean Duration: 0.27 seconds
# -------------------------------------------
# distribution: 2-zipfian-200
# 100 iteractions
# Mean Absolute Error: 1580623.0
# Mean Relative Error: 2.464834544477022e-05
# Mean Duration: 0.27 seconds
# -------------------------------------------
# distribution: 2-zipfian-300
# 100 iteractions
# Mean Absolute Error: 1569759.0
# Mean Relative Error: 2.447893147008301e-05
# Mean Duration: 0.27 seconds
# -------------------------------------------
# distribution: 3-zipfian-100
# 100 iteractions
# Mean Absolute Error: 0.0
# Mean Relative Error: 0.0
# Mean Duration: 0.26 seconds
# -------------------------------------------
# distribution: 3-zipfian-200
# 100 iteractions
# Mean Absolute Error: 0.0
# Mean Relative Error: 0.0
# Mean Duration: 0.26 seconds
# -------------------------------------------
# distribution: 3-zipfian-300
# 100 iteractions
# Mean Absolute Error: 0.0
# Mean Relative Error: 0.0
# Mean Duration: 0.25 seconds
# -------------------------------------------
# distribution: 4-zipfian-100
# 100 iteractions
# Mean Absolute Error: 0.0
# Mean Relative Error: 0.0
# Mean Duration: 0.26 seconds
# -------------------------------------------
# distribution: 4-zipfian-200
# 100 iteractions
# Mean Absolute Error: 0.0
# Mean Relative Error: 0.0
# Mean Duration: 0.26 seconds
# -------------------------------------------
# distribution: 4-zipfian-300
# 100 iteractions
# Mean Absolute Error: 0.0
# Mean Relative Error: 0.0
# Mean Duration: 0.26 seconds
# -------------------------------------------

# %%
keys = list(final_results_agms[0].keys())
print("Fast AGMS")
mean_final_results_agms = []
for k in keys:
  absolute_error = 0
  relative_error = 0
  duration = 0
  for result in final_results_agms:
      absolute_error += result.get(k).get("absolute_error")
      relative_error += result.get(k).get("relative_error")
      duration += result.get(k).get("duration")
  mean_final_results_agms.append([k, absolute_error/q, relative_error/q, duration/q])

  print(f"distribution: {k}")
  print(f"{q} iteractions")
  print(f"Mean Absolute Error: {absolute_error/q}")
  print(f"Mean Relative Error: {relative_error/q}")
  print(f"Mean Duration: {round(duration/q, 2)} seconds")
  print("-------------------------------------------")
# Out:
# Fast AGMS
# distribution: 500000-0.32-weibull-100
# 100 iteractions
# Mean Absolute Error: 1773022.42
# Mean Relative Error: 0.05015211541097598
# Mean Duration: 0.57 seconds
# -------------------------------------------
# distribution: 500000-0.32-weibull-200
# 100 iteractions
# Mean Absolute Error: 1441404.9
# Mean Relative Error: 0.040771906820414754
# Mean Duration: 0.58 seconds
# -------------------------------------------
# distribution: 500000-0.32-weibull-300
# 100 iteractions
# Mean Absolute Error: 936094.38
# Mean Relative Error: 0.026478578528818613
# Mean Duration: 0.6 seconds
# -------------------------------------------
# distribution: 500000-0.32-1-1000-truncated_weibull-100
# 100 iteractions
# Mean Absolute Error: 45979949.8
# Mean Relative Error: 0.0730889087711002
# Mean Duration: 0.61 seconds
# -------------------------------------------
# distribution: 500000-0.32-1-1000-truncated_weibull-200
# 100 iteractions
# Mean Absolute Error: 39996602.56
# Mean Relative Error: 0.0635778866305285
# Mean Duration: 0.56 seconds
# -------------------------------------------
# distribution: 500000-0.32-1-1000-truncated_weibull-300
# 100 iteractions
# Mean Absolute Error: 36889421.14
# Mean Relative Error: 0.05863876641988317
# Mean Duration: 0.58 seconds
# -------------------------------------------
# distribution: 500000-0.15-weibull-100
# 100 iteractions
# Mean Absolute Error: 34779352.7
# Mean Relative Error: 0.014951192925569118
# Mean Duration: 0.6 seconds
# -------------------------------------------
# distribution: 500000-0.15-weibull-200
# 100 iteractions
# Mean Absolute Error: 24455696.54
# Mean Relative Error: 0.010513186954704682
# Mean Duration: 0.61 seconds
# -------------------------------------------
# distribution: 500000-0.15-weibull-300
# 100 iteractions
# Mean Absolute Error: 11801327.8
# Mean Relative Error: 0.005073237855737381
# Mean Duration: 0.59 seconds
# -------------------------------------------
# distribution: 500000-0.15-1-1000-truncated_weibull-100
# 100 iteractions
# Mean Absolute Error: 145523185.84
# Mean Relative Error: 0.09140159077644587
# Mean Duration: 0.58 seconds
# -------------------------------------------
# distribution: 500000-0.15-1-1000-truncated_weibull-200
# 100 iteractions
# Mean Absolute Error: 44544409.78
# Mean Relative Error: 0.02797787782468102
# Mean Duration: 0.58 seconds
# -------------------------------------------
# distribution: 500000-0.15-1-1000-truncated_weibull-300
# 100 iteractions
# Mean Absolute Error: 46246352.48
# Mean Relative Error: 0.029046850231328265
# Mean Duration: 0.59 seconds
# -------------------------------------------
# distribution: 0.03-geometric-100
# 100 iteractions
# Mean Absolute Error: 181910082.88
# Mean Relative Error: 0.07481045483028305
# Mean Duration: 0.32 seconds
# -------------------------------------------
# distribution: 0.03-geometric-200
# 100 iteractions
# Mean Absolute Error: 87255316.2
# Mean Relative Error: 0.03588371676785068
# Mean Duration: 0.32 seconds
# -------------------------------------------
# distribution: 0.03-geometric-300
# 100 iteractions
# Mean Absolute Error: 62422286.88
# Mean Relative Error: 0.025671142572782767
# Mean Duration: 0.32 seconds
# -------------------------------------------
# distribution: 1.1-zipfian
# Mean Duration: 0.0 seconds
# -------------------------------------------
# distribution: 0.03-geometric-200
# 100 iteractions
# Mean Absolute Error: 12875.15209257126
# Mean Relative Error: 5.294901573376308e-06
# Mean Duration: 0.0 seconds
# -------------------------------------------
# distribution: 0.03-geometric-300
# 100 iteractions
# Mean Absolute Error: 32.34471868515015
# Mean Relative Error: 1.330175368998016e-08
# Mean Duration: 0.0 seconds
# -------------------------------------------
# distribution: 1.1-zipfian-100
# 100 iteractions
# Mean Absolute Error: 6208397.074841116
# Mean Relative Error: 0.0029335940383986058
# Mean Duration: 0.28 seconds
# -------------------------------------------
# distribution: 1.1-zipfian-200
# 100 iteractions
# Mean Absolute Error: 2906548.641885097
# Mean Relative Error: 0.0013734034188475118
# Mean Duration: 0.3 seconds
# -------------------------------------------
# distribution: 1.1-zipfian-300
# 100 iteractions
# Mean Absolute Error: 1925817.9588851642
# Mean Relative Error: 0.0009099882006775595
# Mean Duration: 0.29 seconds
# -------------------------------------------
# distribution: 2-zipfian-100
# 100 iteractions
# Mean Absolute Error: 24687.56759857178
# Mean Relative Error: 3.8497965318783364e-07
# Mean Duration: 0.0 seconds
# -------------------------------------------
# distribution: 2-zipfian-200
# 100 iteractions
# Mean Absolute Error: 4069.077565917969
# Mean Relative Error: 6.345347972686134e-08
# Mean Duration: 0.0 seconds
# -------------------------------------------
# distribution: 2-zipfian-300
# 100 iteractions
# Mean Absolute Error: 1443.1459251403808
# Mean Relative Error: 2.2504518338700994e-08
# Mean Duration: 0.0 seconds
# -------------------------------------------
# distribution: 3-zipfian-100
# 100 iteractions
# Mean Absolute Error: 0.0
# Mean Relative Error: 0.0
# Mean Duration: 0.0 seconds
# -------------------------------------------
# distribution: 3-zipfian-200
# 100 iteractions
# Mean Absolute Error: 0.0
# Mean Relative Error: 0.0
# Mean Duration: 0.0 seconds
# -------------------------------------------
# distribution: 3-zipfian-300
# 100 iteractions
# Mean Absolute Error: 0.0
# Mean Relative Error: 0.0
# Mean Duration: 0.0 seconds
# -------------------------------------------
# distribution: 4-zipfian-100
# 100 iteractions
# Mean Absolute Error: 0.0
# Mean Relative Error: 0.0
# Mean Duration: 0.0 seconds
# -------------------------------------------
# distribution: 4-zipfian-200
# 100 iteractions
# Mean Absolute Error: 0.0
# Mean Relative Error: 0.0
# Mean Duration: 0.0 seconds
# -------------------------------------------
# distribution: 4-zipfian-300
# 100 iteractions
# Mean Absolute Error: 0.0
# Mean Relative Error: 0.0
# Mean Duration: 0.0 seconds
# -------------------------------------------

# %%
import pandas as pd
methods = ["Priority Sampling", "Threshold Sampling", "Unbiased Space Saving", "Unbiased Space Saving Coordinated", "Fast AGMS"]
datas = [mean_final_results_priority, mean_final_results_threshold, mean_final_results_unbiased, mean_final_results_unbiased_coordinated, mean_final_results_agms]
datasets = [d[0] for d in mean_final_results_priority]

di = {}
for i in range(len(methods)):
  di[methods[i]] = [d[2] for d in datas[i]]

di_duration = {}
for i in range(len(methods)):
  di_duration[methods[i]] = [d[3] for d in datas[i]]

df = pd.DataFrame(di, index=datasets)
df_2 = pd.DataFrame(di_duration, index=datasets)

df.to_csv("relative_errors.csv")
df_2.to_csv("durations.csv")

# %%
def get_weibull_multiple_params(n):
  data = []
  # Weibull:
  alpha = 500000
  betas = [0.0, 0.05, 0.1, 0.15, 0.2, 0.32, 0.4, 0.6, 0.8, 1]
  a, b = 1, 1000
  for beta in betas:
    s1 = generate_weibull(alpha, beta, n)
    s2 = generate_weibull(alpha, beta, n)
    o = {
       "params": {
        "alpha": alpha,
        "beta": beta,
        "generator": "weibull"
      },
       "s1": s1,
       "s2": s2
    }
    data.append(o)
  return data

# %%
m = [100, 200, 300]

final_results_unbiased = []
final_results_unbiased_coordinated = []
final_results_agms = []
final_results_threshold = []
final_results_priority = []

q = 100
n = 400000
data = get_weibull_multiple_params(n)
for t in range(q):
  iteration_result_unbiased = {}
  iteration_result_unbiased_coordinated = {}
  iteration_result_agms = {}
  iteration_result_threshold = {}
  iteration_result_priority = {}
  print(t)
  for d in data:
    streaming1 = d.get("s1")
    streaming2 = d.get("s1")
    for size in m:
      t1 = time.time()
      sketch1 = unbiased_space_saving(streaming1, n, size)
      sketch2 = unbiased_space_saving(streaming2, n, size)
      t2 = time.time()
      answer1 = get_answer(streaming1, n)
      answer2 = get_answer(streaming2, n)
      v = get_inner_vector(sketch1, sketch2)
      v_ans = get_inner_vector(answer1, answer1)
      ans = calculate_inner_product(v_ans)
      est = calculate_inner_product(v)

      params = list(d.get("params").values())
      params.append(size)
      key = ""
      for p in params:
        key+=f"{p}-"
      key = key[:len(key)-1]
      iteration_result_unbiased[key] = {
          "relative_error": abs(ans - est)/ans,
          "absolute_error": abs(ans - est),
          "duration": t2 - t1
      }

      t1 = time.time()
      est = fast_agms(streaming1, streaming2, size, 4)
      t2 = time.time()
      iteration_result_agms[key] = {
          "relative_error": abs(ans - est)/ans,
          "absolute_error": abs(ans - est),
          "duration": t2 - t1
      }

      t1 = time.time()
      sketch11 = unbiased_space_saving_coordinated(streaming1, n, size)
      sketch22 = unbiased_space_saving_coordinated(streaming2, n, size)
      t2 = time.time()
      v = get_inner_vector(sketch11, sketch22)
      v_ans = get_inner_vector(answer1, answer1)
      ans = calculate_inner_product(v_ans)
      est = calculate_inner_product(v)

      iteration_result_unbiased_coordinated[key] = {
          "relative_error": abs(ans - est)/ans,
          "absolute_error": abs(ans - est),
          "duration": t2 - t1
      }

      t1 = time.time()
      ag1 = get_answer(streaming1, n)
      ag2 = get_answer(streaming2, n)
      sketch111 = threshold_sampling_Chris(ag1, size)
      sketch222 = threshold_sampling_Chris(ag2, size)
      t2 = time.time()
      est = inner_product_from_threshold(sketch111, sketch222)

      iteration_result_threshold[key] = {
          "relative_error": abs(ans - est)/ans,
          "absolute_error": abs(ans - est),
          "duration": t2 - t1
      }

      t1 = time.time()
      sketch1111 = Priority_Sampling_Chris(ag1, size)
      sketch2222 = Priority_Sampling_Chris(ag2, size)
      t2 = time.time()
      est = inner_product_from_threshold(sketch1111, sketch2222)

      iteration_result_priority[key] = {
          "relative_error": abs(ans - est)/ans,
          "absolute_error": abs(ans - est),
          "duration": t2 - t1
      }
  final_results_unbiased.append(iteration_result_unbiased)
  final_results_unbiased_coordinated.append(iteration_result_unbiased_coordinated)
  final_results_agms.append(iteration_result_agms)
  final_results_threshold.append(iteration_result_threshold)
  final_results_priority.append(iteration_result_priority)

# %%
keys = list(final_results_unbiased[0].keys())
print("Unbiased Space Saving")
mean_final_results_unbiased = []
for k in keys:
  absolute_error = 0
  relative_error = 0
  duration = 0
  for result in final_results_unbiased:
      absolute_error += result.get(k).get("absolute_error")
      relative_error += result.get(k).get("relative_error")
      duration += result.get(k).get("duration")
  mean_final_results_unbiased.append([k, absolute_error/q, relative_error/q, duration/q])

  print(f"distribution: {k}")
  print(f"{q} iteractions")
  print(f"Mean Absolute Error: {absolute_error/q}")
  print(f"Mean Relative Error: {relative_error/q}")
  print(f"Mean Duration: {round(duration/q, 2)} seconds")
  print("-------------------------------------------")
# Out:
# Unbiased Space Saving
# distribution: 500000-0.0-weibull-100
# 100 iteractions
# Mean Absolute Error: 0.0
# Mean Relative Error: 0.0
# Mean Duration: 0.12 seconds
# -------------------------------------------
# distribution: 500000-0.0-weibull-200
# 100 iteractions
# Mean Absolute Error: 0.0
# Mean Relative Error: 0.0
# Mean Duration: 0.13 seconds
# -------------------------------------------
# distribution: 500000-0.0-weibull-300
# 100 iteractions
# Mean Absolute Error: 0.0
# Mean Relative Error: 0.0
# Mean Duration: 0.12 seconds
# -------------------------------------------
# distribution: 500000-0.05-weibull-100
# 100 iteractions
# Mean Absolute Error: 6264532.0
# Mean Relative Error: 0.0002514636683861838
# Mean Duration: 0.26 seconds
# -------------------------------------------
# distribution: 500000-0.05-weibull-200
# 100 iteractions
# Mean Absolute Error: 4279544.0
# Mean Relative Error: 0.00017178455362030001
# Mean Duration: 0.26 seconds
# -------------------------------------------
# distribution: 500000-0.05-weibull-300
# 100 iteractions
# Mean Absolute Error: 2961807.0
# Mean Relative Error: 0.00011888946425237831
# Mean Duration: 0.27 seconds
# -------------------------------------------
# distribution: 500000-0.1-weibull-100
# 100 iteractions
# Mean Absolute Error: 14586717.0
# Mean Relative Error: 0.0018246902274057257
# Mean Duration: 0.3 seconds
# -------------------------------------------
# distribution: 500000-0.1-weibull-200
# 100 iteractions
# Mean Absolute Error: 10981357.0
# Mean Relative Error: 0.0013736864026054332
# Mean Duration: 0.32 seconds
# -------------------------------------------
# distribution: 500000-0.1-weibull-300
# 100 iteractions
# Mean Absolute Error: 7622718.0
# Mean Relative Error: 0.0009535455470116904
# Mean Duration: 0.29 seconds
# -------------------------------------------
# distribution: 500000-0.15-weibull-100
# 100 iteractions
# Mean Absolute Error: 17536431.0
# Mean Relative Error: 0.007453656037028003
# Mean Duration: 0.32 seconds
# -------------------------------------------
# distribution: 500000-0.15-weibull-200
# 100 iteractions
# Mean Absolute Error: 13381186.0
# Mean Relative Error: 0.005687517477843398
# Mean Duration: 0.32 seconds
# -------------------------------------------
# distribution: 500000-0.15-weibull-300
# 100 iteractions
# Mean Absolute Error: 10465004.0
# Mean Relative Error: 0.004448028235740919
# Mean Duration: 0.31 seconds
# -------------------------------------------
# distribution: 500000-0.2-weibull-100
# 100 iteractions
# Mean Absolute Error: 54919409.0
# Mean Relative Error: 0.0817713938162978
# Mean Duration: 0.34 seconds
# -------------------------------------------
# distribution: 500000-0.2-weibull-200
# 100 iteractions
# Mean Absolute Error: 54579827.0
# Mean Relative Error: 0.08126577851634219
# Mean Duration: 0.34 seconds
# -------------------------------------------
# distribution: 500000-0.2-weibull-300
# 100 iteractions
# Mean Absolute Error: 52679476.56
# Mean Relative Error: 0.0784362814942925
# Mean Duration: 0.34 seconds
# -------------------------------------------
# distribution: 500000-0.32-weibull-100
# 100 iteractions
# Mean Absolute Error: 35337536.0
# Mean Relative Error: 0.998361206052447
# Mean Duration: 0.35 seconds
# -------------------------------------------
# distribution: 500000-0.32-weibull-200
# 100 iteractions
# Mean Absolute Error: 33692508.0
# Mean Relative Error: 0.9518856357673532
# Mean Duration: 0.36 seconds
# -------------------------------------------
# distribution: 500000-0.32-weibull-300
# 100 iteractions
# Mean Absolute Error: 33662675.0
# Mean Relative Error: 0.9510427895128697
# Mean Duration: 0.35 seconds
# -------------------------------------------
# distribution: 500000-0.4-weibull-100
# 100 iteractions
# Mean Absolute Error: 3049449.0
# Mean Relative Error: 0.4846651264775426
# Mean Duration: 0.33 seconds
# -------------------------------------------
# distribution: 500000-0.4-weibull-200
# 100 iteractions
# Mean Absolute Error: 2762914.0
# Mean Relative Error: 0.4391245970195169
# Mean Duration: 0.32 seconds
# -------------------------------------------
# distribution: 500000-0.4-weibull-300
# 100 iteractions
# Mean Absolute Error: 2710870.0
# Mean Relative Error: 0.4308529676719221
# Mean Duration: 0.34 seconds
# -------------------------------------------
# distribution: 500000-0.6-weibull-100
# 100 iteractions
# Mean Absolute Error: 778838.0
# Mean Relative Error: 0.9996200910241377
# Mean Duration: 0.32 seconds
# -------------------------------------------
# distribution: 500000-0.6-weibull-200
# 100 iteractions
# Mean Absolute Error: 777976.0
# Mean Relative Error: 0.9985137344795625
# Mean Duration: 0.32 seconds
# -------------------------------------------
# distribution: 500000-0.6-weibull-300
# 100 iteractions
# Mean Absolute Error: 776895.0
# Mean Relative Error: 0.9971262966319034
# Mean Duration: 0.35 seconds
# -------------------------------------------
# distribution: 500000-0.8-weibull-100
# 100 iteractions
# Mean Absolute Error: 585544.0
# Mean Relative Error: 0.9993241628835712
# Mean Duration: 0.34 seconds
# -------------------------------------------
# distribution: 500000-0.8-weibull-200
# 100 iteractions
# Mean Absolute Error: 585188.0
# Mean Relative Error: 0.9987165921425418
# Mean Duration: 0.34 seconds
# -------------------------------------------
# distribution: 500000-0.8-weibull-300
# 100 iteractions
# Mean Absolute Error: 584886.0
# Mean Relative Error: 0.9982011810082946
# Mean Duration: 0.34 seconds
# -------------------------------------------
# distribution: 500000-1-weibull-100
# 100 iteractions
# Mean Absolute Error: 559292.0
# Mean Relative Error: 0.9995532060149196
# Mean Duration: 0.32 seconds
# -------------------------------------------
# distribution: 500000-1-weibull-200
# 100 iteractions
# Mean Absolute Error: 559085.0
# Mean Relative Error: 0.9991832605952734
# Mean Duration: 0.32 seconds
# -------------------------------------------
# distribution: 500000-1-weibull-300
# 100 iteractions
# Mean Absolute Error: 558802.0
# Mean Relative Error: 0.9986774898041623
# Mean Duration: 0.34 seconds
# -------------------------------------------

# %%
keys = list(final_results_unbiased_coordinated[0].keys())
print("Unbiased Space Saving Coordinated")
mean_final_results_unbiased_coordinated = []
for k in keys:
  absolute_error = 0
  relative_error = 0
  duration = 0
  for result in final_results_unbiased_coordinated:
      absolute_error += result.get(k).get("absolute_error")
      relative_error += result.get(k).get("relative_error")
      duration += result.get(k).get("duration")
  mean_final_results_unbiased_coordinated.append([k, absolute_error/q, relative_error/q, duration/q])

  print(f"distribution: {k}")
  print(f"{q} iteractions")
  print(f"Mean Absolute Error: {absolute_error/q}")
  print(f"Mean Relative Error: {relative_error/q}")
  print(f"Mean Duration: {round(duration/q, 2)} seconds")
  print("-------------------------------------------")
# Out:
# Unbiased Space Saving Coordinated
# distribution: 500000-0.0-weibull-100
# 100 iteractions
# Mean Absolute Error: 0.0
# Mean Relative Error: 0.0
# Mean Duration: 0.33 seconds
# -------------------------------------------
# distribution: 500000-0.0-weibull-200
# 100 iteractions
# Mean Absolute Error: 0.0
# Mean Relative Error: 0.0
# Mean Duration: 0.35 seconds
# -------------------------------------------
# distribution: 500000-0.0-weibull-300
# 100 iteractions
# Mean Absolute Error: 0.0
# Mean Relative Error: 0.0
# Mean Duration: 0.34 seconds
# -------------------------------------------
# distribution: 500000-0.05-weibull-100
# 100 iteractions
# Mean Absolute Error: 6264532.0
# Mean Relative Error: 0.0002514636683861838
# Mean Duration: 1.69 seconds
# -------------------------------------------
# distribution: 500000-0.05-weibull-200
# 100 iteractions
# Mean Absolute Error: 4279544.0
# Mean Relative Error: 0.00017178455362030001
# Mean Duration: 1.68 seconds
# -------------------------------------------
# distribution: 500000-0.05-weibull-300
# 100 iteractions
# Mean Absolute Error: 2961807.0
# Mean Relative Error: 0.00011888946425237831
# Mean Duration: 1.74 seconds
# -------------------------------------------
# distribution: 500000-0.1-weibull-100
# 100 iteractions
# Mean Absolute Error: 14586717.0
# Mean Relative Error: 0.0018246902274057257
# Mean Duration: 0.56 seconds
# -------------------------------------------
# distribution: 500000-0.1-weibull-200
# 100 iteractions
# Mean Absolute Error: 10981357.0
# Mean Relative Error: 0.0013736864026054332
# Mean Duration: 0.55 seconds
# -------------------------------------------
# distribution: 500000-0.1-weibull-300
# 100 iteractions
# Mean Absolute Error: 7622718.0
# Mean Relative Error: 0.0009535455470116904
# Mean Duration: 0.56 seconds
# -------------------------------------------
# distribution: 500000-0.15-weibull-100
# 100 iteractions
# Mean Absolute Error: 17530723.76
# Mean Relative Error: 0.00745123024104473
# Mean Duration: 0.61 seconds
# -------------------------------------------
# distribution: 500000-0.15-weibull-200
# 100 iteractions
# Mean Absolute Error: 13381186.0
# Mean Relative Error: 0.005687517477843398
# Mean Duration: 0.58 seconds
# -------------------------------------------
# distribution: 500000-0.15-weibull-300
# 100 iteractions
# Mean Absolute Error: 10465004.0
# Mean Relative Error: 0.004448028235740919
# Mean Duration: 0.56 seconds
# -------------------------------------------
# distribution: 500000-0.2-weibull-100
# 100 iteractions
# Mean Absolute Error: 54919409.0
# Mean Relative Error: 0.0817713938162978
# Mean Duration: 0.53 seconds
# -------------------------------------------
# distribution: 500000-0.2-weibull-200
# 100 iteractions
# Mean Absolute Error: 54572474.36
# Mean Relative Error: 0.08125483091818014
# Mean Duration: 0.55 seconds
# -------------------------------------------
# distribution: 500000-0.2-weibull-300
# 100 iteractions
# Mean Absolute Error: 52688016.0
# Mean Relative Error: 0.07844899615972546
# Mean Duration: 0.53 seconds
# -------------------------------------------
# distribution: 500000-0.32-weibull-100
# 100 iteractions
# Mean Absolute Error: 35337536.0
# Mean Relative Error: 0.998361206052447
# Mean Duration: 0.59 seconds
# -------------------------------------------
# distribution: 500000-0.32-weibull-200
# 100 iteractions
# Mean Absolute Error: 33692508.0
# Mean Relative Error: 0.9518856357673532
# Mean Duration: 0.57 seconds
# -------------------------------------------
# distribution: 500000-0.32-weibull-300
# 100 iteractions
# Mean Absolute Error: 33662675.0
# Mean Relative Error: 0.9510427895128697
# Mean Duration: 0.59 seconds
# -------------------------------------------
# distribution: 500000-0.4-weibull-100
# 100 iteractions
# Mean Absolute Error: 3049449.0
# Mean Relative Error: 0.4846651264775426
# Mean Duration: 0.46 seconds
# -------------------------------------------
# distribution: 500000-0.4-weibull-200
# 100 iteractions
# Mean Absolute Error: 2762914.0
# Mean Relative Error: 0.4391245970195169
# Mean Duration: 0.45 seconds
# -------------------------------------------
# distribution: 500000-0.4-weibull-300
# 100 iteractions
# Mean Absolute Error: 2710870.0
# Mean Relative Error: 0.4308529676719221
# Mean Duration: 0.49 seconds
# -------------------------------------------
# distribution: 500000-0.6-weibull-100
# 100 iteractions
# Mean Absolute Error: 778838.0
# Mean Relative Error: 0.9996200910241377
# Mean Duration: 0.45 seconds
# -------------------------------------------
# distribution: 500000-0.6-weibull-200
# 100 iteractions
# Mean Absolute Error: 777976.0
# Mean Relative Error: 0.9985137344795625
# Mean Duration: 0.45 seconds
# -------------------------------------------
# distribution: 500000-0.6-weibull-300
# 100 iteractions
# Mean Absolute Error: 776895.0
# Mean Relative Error: 0.9971262966319034
# Mean Duration: 0.49 seconds
# -------------------------------------------
# distribution: 500000-0.8-weibull-100
# 100 iteractions
# Mean Absolute Error: 585544.0
# Mean Relative Error: 0.9993241628835712
# Mean Duration: 0.48 seconds
# -------------------------------------------
# distribution: 500000-0.8-weibull-200
# 100 iteractions
# Mean Absolute Error: 585188.0
# Mean Relative Error: 0.9987165921425418
# Mean Duration: 0.45 seconds
# -------------------------------------------
# distribution: 500000-0.8-weibull-300
# 100 iteractions
# Mean Absolute Error: 584886.0
# Mean Relative Error: 0.9982011810082946
# Mean Duration: 0.5 seconds
# -------------------------------------------
# distribution: 500000-1-weibull-100
# 100 iteractions
# Mean Absolute Error: 559292.0
# Mean Relative Error: 0.9995532060149196
# Mean Duration: 0.45 seconds
# -------------------------------------------
# distribution: 500000-1-weibull-200
# 100 iteractions
# Mean Absolute Error: 559085.0
# Mean Relative Error: 0.9991832605952734
# Mean Duration: 0.46 seconds
# -------------------------------------------
# distribution: 500000-1-weibull-300
# 100 iteractions
# Mean Absolute Error: 555414.0
# Mean Relative Error: 0.9926225377183492
# Mean Duration: 0.47 seconds
# -------------------------------------------

# %%
keys = list(final_results_agms[0].keys())
print("Fast AGMS")
mean_final_results_agms = []
for k in keys:
  absolute_error = 0
  relative_error = 0
  duration = 0
  for result in final_results_agms:
      absolute_error += result.get(k).get("absolute_error")
      relative_error += result.get(k).get("relative_error")
      duration += result.get(k).get("duration")
  mean_final_results_agms.append([k, absolute_error/q, relative_error/q, duration/q])

  print(f"distribution: {k}")
  print(f"{q} iteractions")
  print(f"Mean Absolute Error: {absolute_error/q}")
  print(f"Mean Relative Error: {relative_error/q}")
  print(f"Mean Duration: {round(duration/q, 2)} seconds")
  print("-------------------------------------------")
# Out:
# Fast AGMS
# distribution: 500000-0.0-weibull-100
# 100 iteractions
# Mean Absolute Error: 0.0
# Mean Relative Error: 0.0
# Mean Duration: 0.64 seconds
# -------------------------------------------
# distribution: 500000-0.0-weibull-200
# 100 iteractions
# Mean Absolute Error: 0.0
# Mean Relative Error: 0.0
# Mean Duration: 0.6 seconds
# -------------------------------------------
# distribution: 500000-0.0-weibull-300
# 100 iteractions
# Mean Absolute Error: 0.0
# Mean Relative Error: 0.0
# Mean Duration: 0.6 seconds
# -------------------------------------------
# distribution: 500000-0.05-weibull-100
# 100 iteractions
# Mean Absolute Error: 53406820.5
# Mean Relative Error: 0.0021437954183604556
# Mean Duration: 2.43 seconds
# -------------------------------------------
# distribution: 500000-0.05-weibull-200
# 100 iteractions
# Mean Absolute Error: 94101591.44
# Mean Relative Error: 0.0037773183031837537
# Mean Duration: 2.46 seconds
# -------------------------------------------
# distribution: 500000-0.05-weibull-300
# 100 iteractions
# Mean Absolute Error: 30386497.02
# Mean Relative Error: 0.001219739959833401
# Mean Duration: 2.55 seconds
# -------------------------------------------
# distribution: 500000-0.1-weibull-100
# 100 iteractions
# Mean Absolute Error: 69771007.88
# Mean Relative Error: 0.008727836170050058
# Mean Duration: 0.76 seconds
# -------------------------------------------
# distribution: 500000-0.1-weibull-200
# 100 iteractions
# Mean Absolute Error: 73277892.68
# Mean Relative Error: 0.009166521476908192
# Mean Duration: 0.8 seconds
# -------------------------------------------
# distribution: 500000-0.1-weibull-300
# 100 iteractions
# Mean Absolute Error: 16349230.3
# Mean Relative Error: 0.002045167583220792
# Mean Duration: 0.79 seconds
# -------------------------------------------
# distribution: 500000-0.15-weibull-100
# 100 iteractions
# Mean Absolute Error: 49399639.42
# Mean Relative Error: 0.02099674218715828
# Mean Duration: 0.79 seconds
# -------------------------------------------
# distribution: 500000-0.15-weibull-200
# 100 iteractions
# Mean Absolute Error: 26970435.52
# Mean Relative Error: 0.011463469934955568
# Mean Duration: 0.81 seconds
# -------------------------------------------
# distribution: 500000-0.15-weibull-300
# 100 iteractions
# Mean Absolute Error: 14280530.16
# Mean Relative Error: 0.006069773253123439
# Mean Duration: 0.77 seconds
# -------------------------------------------
# distribution: 500000-0.2-weibull-100
# 100 iteractions
# Mean Absolute Error: 20536620.16
# Mean Relative Error: 0.030577678917831804
# Mean Duration: 0.72 seconds
# -------------------------------------------
# distribution: 500000-0.2-weibull-200
# 100 iteractions
# Mean Absolute Error: 14568035.86
# Mean Relative Error: 0.021690848811537822
# Mean Duration: 0.73 seconds
# -------------------------------------------
# distribution: 500000-0.2-weibull-300
# 100 iteractions
# Mean Absolute Error: 9576699.28
# Mean Relative Error: 0.014259076391101294
# Mean Duration: 0.76 seconds
# -------------------------------------------
# distribution: 500000-0.32-weibull-100
# 100 iteractions
# Mean Absolute Error: 2157417.82
# Mean Relative Error: 0.060951681994303106
# Mean Duration: 0.79 seconds
# -------------------------------------------
# distribution: 500000-0.32-weibull-200
# 100 iteractions
# Mean Absolute Error: 1292018.22
# Mean Relative Error: 0.036502286643894315
# Mean Duration: 0.76 seconds
# -------------------------------------------
# distribution: 500000-0.32-weibull-300
# 100 iteractions
# Mean Absolute Error: 980776.32
# Mean Relative Error: 0.027709035222571256
# Mean Duration: 0.78 seconds
# -------------------------------------------
# distribution: 500000-0.4-weibull-100
# 100 iteractions
# Mean Absolute Error: 617053.38
# Mean Relative Error: 0.0980715711136979
# Mean Duration: 0.62 seconds
# -------------------------------------------
# distribution: 500000-0.4-weibull-200
# 100 iteractions
# Mean Absolute Error: 378627.68
# Mean Relative Error: 0.060177308233421316
# Mean Duration: 0.65 seconds
# -------------------------------------------
# distribution: 500000-0.4-weibull-300
# 100 iteractions
# Mean Absolute Error: 301303.98
# Mean Relative Error: 0.04788784189369516
# Mean Duration: 0.67 seconds
# -------------------------------------------
# distribution: 500000-0.6-weibull-100
# 100 iteractions
# Mean Absolute Error: 80849.72
# Mean Relative Error: 0.10376869704056042
# Mean Duration: 0.6 seconds
# -------------------------------------------
# distribution: 500000-0.6-weibull-200
# 100 iteractions
# Mean Absolute Error: 58396.98
# Mean Relative Error: 0.07495113805840846
# Mean Duration: 0.62 seconds
# -------------------------------------------
# distribution: 500000-0.6-weibull-300
# 100 iteractions
# Mean Absolute Error: 50474.42
# Mean Relative Error: 0.06478272030228434
# Mean Duration: 0.67 seconds
# -------------------------------------------
# distribution: 500000-0.8-weibull-100
# 100 iteractions
# Mean Absolute Error: 56428.78
# Mean Relative Error: 0.09630470696658362
# Mean Duration: 0.62 seconds
# -------------------------------------------
# distribution: 500000-0.8-weibull-200
# 100 iteractions
# Mean Absolute Error: 46850.72
# Mean Relative Error: 0.07995822097825714
# Mean Duration: 0.63 seconds
# -------------------------------------------
# distribution: 500000-0.8-weibull-300
# 100 iteractions
# Mean Absolute Error: 39747.08
# Mean Relative Error: 0.06783472710516436
# Mean Duration: 0.66 seconds
# -------------------------------------------
# distribution: 500000-1-weibull-100
# 100 iteractions
# Mean Absolute Error: 61340.22
# Mean Relative Error: 0.10962576535809644
# Mean Duration: 0.62 seconds
# -------------------------------------------
# distribution: 500000-1-weibull-200
# 100 iteractions
# Mean Absolute Error: 43964.3
# Mean Relative Error: 0.07857193919312583
# Mean Duration: 0.62 seconds
# -------------------------------------------
# distribution: 500000-1-weibull-300
# 100 iteractions
# Mean Absolute Error: 40538.84
# Mean Relative Error: 0.07245003949658829
# Mean Duration: 0.65 seconds
# -------------------------------------------

# %%
keys = list(final_results_threshold[0].keys())
print("Threshold Sampling")
mean_final_results_threshold = []
for k in keys:
  absolute_error = 0
  relative_error = 0
  duration = 0
  for result in final_results_threshold:
      absolute_error += result.get(k).get("absolute_error")
      relative_error += result.get(k).get("relative_error")
      duration += result.get(k).get("duration")
  mean_final_results_threshold.append([k, absolute_error/q, relative_error/q, duration/q])

  print(f"distribution: {k}")
  print(f"{q} iteractions")
  print(f"Mean Absolute Error: {absolute_error/q}")
  print(f"Mean Relative Error: {relative_error/q}")
  print(f"Mean Duration: {round(duration/q, 2)} seconds")
  print("-------------------------------------------")
# Out:
# Threshold Sampling
# distribution: 500000-0.0-weibull-100
# 100 iteractions
# Mean Absolute Error: 0.0
# Mean Relative Error: 0.0
# Mean Duration: 0.05 seconds
# -------------------------------------------
# distribution: 500000-0.0-weibull-200
# 100 iteractions
# Mean Absolute Error: 0.0
# Mean Relative Error: 0.0
# Mean Duration: 0.05 seconds
# -------------------------------------------
# distribution: 500000-0.0-weibull-300
# 100 iteractions
# Mean Absolute Error: 0.0
# Mean Relative Error: 0.0
# Mean Duration: 0.05 seconds
# -------------------------------------------
# distribution: 500000-0.05-weibull-100
# 100 iteractions
# Mean Absolute Error: 76442375.3764
# Mean Relative Error: 0.003068462278156334
# Mean Duration: 1.64 seconds
# -------------------------------------------
# distribution: 500000-0.05-weibull-200
# 100 iteractions
# Mean Absolute Error: 73279255.03479996
# Mean Relative Error: 0.0029414919243221285
# Mean Duration: 1.65 seconds
# -------------------------------------------
# distribution: 500000-0.05-weibull-300
# 100 iteractions
# Mean Absolute Error: 50344831.175600395
# Mean Relative Error: 0.0020208845499870725
# Mean Duration: 1.71 seconds
# -------------------------------------------
# distribution: 500000-0.1-weibull-100
# 100 iteractions
# Mean Absolute Error: 58379290.39799997
# Mean Relative Error: 0.007302816711403376
# Mean Duration: 0.6 seconds
# -------------------------------------------
# distribution: 500000-0.1-weibull-200
# 100 iteractions
# Mean Absolute Error: 46465735.81050007
# Mean Relative Error: 0.005812519297017685
# Mean Duration: 0.59 seconds
# -------------------------------------------
# distribution: 500000-0.1-weibull-300
# 100 iteractions
# Mean Absolute Error: 38172594.57826666
# Mean Relative Error: 0.004775108770649633
# Mean Duration: 0.59 seconds
# -------------------------------------------
# distribution: 500000-0.15-weibull-100
# 100 iteractions
# Mean Absolute Error: 36438057.76100013
# Mean Relative Error: 0.015487572654199375
# Mean Duration: 0.63 seconds
# -------------------------------------------
# distribution: 500000-0.15-weibull-200
# 100 iteractions
# Mean Absolute Error: 27296060.11250007
# Mean Relative Error: 0.011601872880782621
# Mean Duration: 0.64 seconds
# -------------------------------------------
# distribution: 500000-0.15-weibull-300
# 100 iteractions
# Mean Absolute Error: 20937998.567000195
# Mean Relative Error: 0.008899452769050041
# Mean Duration: 0.65 seconds
# -------------------------------------------
# distribution: 500000-0.2-weibull-100
# 100 iteractions
# Mean Absolute Error: 19860341.276000004
# Mean Relative Error: 0.02957074406619839
# Mean Duration: 0.68 seconds
# -------------------------------------------
# distribution: 500000-0.2-weibull-200
# 100 iteractions
# Mean Absolute Error: 14299808.35799992
# Mean Relative Error: 0.02129147567373859
# Mean Duration: 0.7 seconds
# -------------------------------------------
# distribution: 500000-0.2-weibull-300
# 100 iteractions
# Mean Absolute Error: 12098627.916666688
# Mean Relative Error: 0.018014062533167598
# Mean Duration: 0.68 seconds
# -------------------------------------------
# distribution: 500000-0.32-weibull-100
# 100 iteractions
# Mean Absolute Error: 4122884.1248000027
# Mean Relative Error: 0.1164803218665219
# Mean Duration: 0.74 seconds
# -------------------------------------------
# distribution: 500000-0.32-weibull-200
# 100 iteractions
# Mean Absolute Error: 3336949.390399997
# Mean Relative Error: 0.09427597945526578
# Mean Duration: 0.77 seconds
# -------------------------------------------
# distribution: 500000-0.32-weibull-300
# 100 iteractions
# Mean Absolute Error: 2949893.762999997
# Mean Relative Error: 0.08334082758218526
# Mean Duration: 0.76 seconds
# -------------------------------------------
# distribution: 500000-0.4-weibull-100
# 100 iteractions
# Mean Absolute Error: 1837437.644799999
# Mean Relative Error: 0.29203372429300833
# Mean Duration: 0.75 seconds
# -------------------------------------------
# distribution: 500000-0.4-weibull-200
# 100 iteractions
# Mean Absolute Error: 1649081.7968000013
# Mean Relative Error: 0.2620973289331563
# Mean Duration: 0.78 seconds
# -------------------------------------------
# distribution: 500000-0.4-weibull-300
# 100 iteractions
# Mean Absolute Error: 1505272.0973333323
# Mean Relative Error: 0.2392408895630569
# Mean Duration: 0.76 seconds
# -------------------------------------------
# distribution: 500000-0.6-weibull-100
# 100 iteractions
# Mean Absolute Error: 744909.3655999997
# Mean Relative Error: 0.9560734939047719
# Mean Duration: 0.8 seconds
# -------------------------------------------
# distribution: 500000-0.6-weibull-200
# 100 iteractions
# Mean Absolute Error: 734727.0209999995
# Mean Relative Error: 0.9430046962396714
# Mean Duration: 0.83 seconds
# -------------------------------------------
# distribution: 500000-0.6-weibull-300
# 100 iteractions
# Mean Absolute Error: 727429.1325333328
# Mean Relative Error: 0.9336380295730042
# Mean Duration: 0.87 seconds
# -------------------------------------------
# distribution: 500000-0.8-weibull-100
# 100 iteractions
# Mean Absolute Error: 585354.06
# Mean Relative Error: 0.9989999999999999
# Mean Duration: 0.87 seconds
# -------------------------------------------
# distribution: 500000-0.8-weibull-200
# 100 iteractions
# Mean Absolute Error: 585119.6839999999
# Mean Relative Error: 0.9985999999999998
# Mean Duration: 0.87 seconds
# -------------------------------------------
# distribution: 500000-0.8-weibull-300
# 100 iteractions
# Mean Absolute Error: 584299.3680000004
# Mean Relative Error: 0.9972000000000009
# Mean Duration: 0.9 seconds
# -------------------------------------------
# distribution: 500000-1-weibull-100
# 100 iteractions
# Mean Absolute Error: 559374.1373999999
# Mean Relative Error: 0.9997
# Mean Duration: 0.88 seconds
# -------------------------------------------
# distribution: 500000-1-weibull-200
# 100 iteractions
# Mean Absolute Error: 558618.7556999999
# Mean Relative Error: 0.9983500000000002
# Mean Duration: 0.9 seconds
# -------------------------------------------
# distribution: 500000-1-weibull-300
# 100 iteractions
# Mean Absolute Error: 558348.3103999997
# Mean Relative Error: 0.9978666666666675
# Mean Duration: 0.9 seconds
# -------------------------------------------

# %%
keys = list(final_results_priority[0].keys())
print("Priority Sampling")
mean_final_results_priority = []
for k in keys:
  absolute_error = 0
  relative_error = 0
  duration = 0
  for result in final_results_priority:
      absolute_error += result.get(k).get("absolute_error")
      relative_error += result.get(k).get("relative_error")
      duration += result.get(k).get("duration")
  mean_final_results_priority.append([k, absolute_error/q, relative_error/q, duration/q])

  print(f"distribution: {k}")
  print(f"{q} iteractions")
  print(f"Mean Absolute Error: {absolute_error/q}")
  print(f"Mean Relative Error: {relative_error/q}")
  print(f"Mean Duration: {round(duration/q, 2)} seconds")
  print("-------------------------------------------")
# Out:
# Priority Sampling
# distribution: 500000-0.0-weibull-100
# 100 iteractions
# Mean Absolute Error: 0.0
# Mean Relative Error: 0.0
# Mean Duration: 0.0 seconds
# -------------------------------------------
# distribution: 500000-0.0-weibull-200
# 100 iteractions
# Mean Absolute Error: 0.0
# Mean Relative Error: 0.0
# Mean Duration: 0.0 seconds
# -------------------------------------------
# distribution: 500000-0.0-weibull-300
# 100 iteractions
# Mean Absolute Error: 0.0
# Mean Relative Error: 0.0
# Mean Duration: 0.0 seconds
# -------------------------------------------
# distribution: 500000-0.05-weibull-100
# 100 iteractions
# Mean Absolute Error: 874567.2084947205
# Mean Relative Error: 3.510587518722023e-05
# Mean Duration: 1.49 seconds
# -------------------------------------------
# distribution: 500000-0.05-weibull-200
# 100 iteractions
# Mean Absolute Error: 562320.7666450882
# Mean Relative Error: 2.2572036153747036e-05
# Mean Duration: 1.53 seconds
# -------------------------------------------
# distribution: 500000-0.05-weibull-300
# 100 iteractions
# Mean Absolute Error: 457701.9797490311
# Mean Relative Error: 1.83725486365638e-05
# Mean Duration: 1.55 seconds
# -------------------------------------------
# distribution: 500000-0.1-weibull-100
# 100 iteractions
# Mean Absolute Error: 2092322.0760730363
# Mean Relative Error: 0.00026173399023205396
# Mean Duration: 0.45 seconds
# -------------------------------------------
# distribution: 500000-0.1-weibull-200
# 100 iteractions
# Mean Absolute Error: 1253414.4676461315
# Mean Relative Error: 0.0001567928636719867
# Mean Duration: 0.44 seconds
# -------------------------------------------
# distribution: 500000-0.1-weibull-300
# 100 iteractions
# Mean Absolute Error: 971481.7792219258
# Mean Relative Error: 0.00012152517311804824
# Mean Duration: 0.46 seconds
# -------------------------------------------
# distribution: 500000-0.15-weibull-100
# 100 iteractions
# Mean Absolute Error: 2927166.283955965
# Mean Relative Error: 0.0012441579842439575
# Mean Duration: 0.49 seconds
# -------------------------------------------
# distribution: 500000-0.15-weibull-200
# 100 iteractions
# Mean Absolute Error: 1852946.3811845733
# Mean Relative Error: 0.0007875733084118202
# Mean Duration: 0.49 seconds
# -------------------------------------------
# distribution: 500000-0.15-weibull-300
# 100 iteractions
# Mean Absolute Error: 1429803.7068854524
# Mean Relative Error: 0.0006077214361115892
# Mean Duration: 0.53 seconds
# -------------------------------------------
# distribution: 500000-0.2-weibull-100
# 100 iteractions
# Mean Absolute Error: 3090536.4020917034
# Mean Relative Error: 0.004601605768172868
# Mean Duration: 0.56 seconds
# -------------------------------------------
# distribution: 500000-0.2-weibull-200
# 100 iteractions
# Mean Absolute Error: 2045294.2989949726
# Mean Relative Error: 0.003045308910613855
# Mean Duration: 0.57 seconds
# -------------------------------------------
# distribution: 500000-0.2-weibull-300
# 100 iteractions
# Mean Absolute Error: 1625575.5747142828
# Mean Relative Error: 0.0024203752902387625
# Mean Duration: 0.55 seconds
# -------------------------------------------
# distribution: 500000-0.32-weibull-100
# 100 iteractions
# Mean Absolute Error: 2146290.9263176783
# Mean Relative Error: 0.060637323375855645
# Mean Duration: 0.6 seconds
# -------------------------------------------
# distribution: 500000-0.32-weibull-200
# 100 iteractions
# Mean Absolute Error: 1681404.4672413627
# Mean Relative Error: 0.047503283527664635
# Mean Duration: 0.62 seconds
# -------------------------------------------
# distribution: 500000-0.32-weibull-300
# 100 iteractions
# Mean Absolute Error: 1467315.4814856756
# Mean Relative Error: 0.04145481036808747
# Mean Duration: 0.62 seconds
# -------------------------------------------
# distribution: 500000-0.4-weibull-100
# 100 iteractions
# Mean Absolute Error: 1496610.538305504
# Mean Relative Error: 0.23786426198157742
# Mean Duration: 0.63 seconds
# -------------------------------------------
# distribution: 500000-0.4-weibull-200
# 100 iteractions
# Mean Absolute Error: 1289382.8385718963
# Mean Relative Error: 0.2049284629893532
# Mean Duration: 0.66 seconds
# -------------------------------------------
# distribution: 500000-0.4-weibull-300
# 100 iteractions
# Mean Absolute Error: 1188009.3907946823
# Mean Relative Error: 0.18881664249705846
# Mean Duration: 0.65 seconds
# -------------------------------------------
# distribution: 500000-0.6-weibull-100
# 100 iteractions
# Mean Absolute Error: 742467.6302692029
# Mean Relative Error: 0.952939584550543
# Mean Duration: 0.7 seconds
# -------------------------------------------
# distribution: 500000-0.6-weibull-200
# 100 iteractions
# Mean Absolute Error: 733741.0493063992
# Mean Relative Error: 0.941739224968233
# Mean Duration: 0.72 seconds
# -------------------------------------------
# distribution: 500000-0.6-weibull-300
# 100 iteractions
# Mean Absolute Error: 725957.7011233493
# Mean Relative Error: 0.9317494822756412
# Mean Duration: 0.75 seconds
# -------------------------------------------
# distribution: 500000-0.8-weibull-100
# 100 iteractions
# Mean Absolute Error: 585702.8760803229
# Mean Relative Error: 0.9995953102370941
# Mean Duration: 0.75 seconds
# -------------------------------------------
# distribution: 500000-0.8-weibull-200
# 100 iteractions
# Mean Absolute Error: 585060.6054781745
# Mean Relative Error: 0.9984991730862793
# Mean Duration: 0.76 seconds
# -------------------------------------------
# distribution: 500000-0.8-weibull-300
# 100 iteractions
# Mean Absolute Error: 584534.2449042875
# Mean Relative Error: 0.9976008548730035
# Mean Duration: 0.76 seconds
# -------------------------------------------
# distribution: 500000-1-weibull-100
# 100 iteractions
# Mean Absolute Error: 559116.5975884206
# Mean Relative Error: 0.99923973104507
# Mean Duration: 0.77 seconds
# -------------------------------------------
# distribution: 500000-1-weibull-200
# 100 iteractions
# Mean Absolute Error: 558789.2569915359
# Mean Relative Error: 0.9986547158060267
# Mean Duration: 0.79 seconds
# -------------------------------------------
# distribution: 500000-1-weibull-300
# 100 iteractions
# Mean Absolute Error: 558534.7085025025
# Mean Relative Error: 0.9981997928707805
# Mean Duration: 0.78 seconds
# -------------------------------------------

# %%
import pandas as pd
methods = ["Priority Sampling", "Threshold Sampling", "Unbiased Space Saving", "Unbiased Space Saving Coordinated", "Fast AGMS"]
datas = [mean_final_results_priority, mean_final_results_threshold, mean_final_results_unbiased, mean_final_results_unbiased_coordinated, mean_final_results_agms]
datasets = [d[0] for d in mean_final_results_priority]

di = {}
for i in range(len(methods)):
  di[methods[i]] = [d[2] for d in datas[i]]

di_duration = {}
for i in range(len(methods)):
  di_duration[methods[i]] = [d[3] for d in datas[i]]

df = pd.DataFrame(di, index=datasets)
df_2 = pd.DataFrame(di_duration, index=datasets)

df.to_csv("relative_errors_weibull.csv")
df_2.to_csv("durations_weibull.csv")

# %%
# variar o k de 1 a 20
def shift(s1, k, n):
  new_s = []
  shifted = {}
  f = get_answer(s1, n)
  sorted_d = sorted(f.items(), key=lambda x: x[1], reverse=True) #sorted[i][0] = key, sorted[i][1] = frequency
  for i in range(len(sorted_d)):
    new_index = i + k
    if new_index < len(sorted_d):
      shifted[sorted_d[i][0]] = sorted_d[new_index][0]
    else:
      dif = new_index - len(sorted_d)
      shifted[sorted_d[i][0]] = sorted_d[dif][0]

  for e in s1:
    new_s.append(shifted[e])
  return new_s

def get_weibull_shifted(n):
  data = []
  # Weibull:
  alpha = 500000
  beta = 0.15
  for k in range(1, 20):
    s1 = generate_weibull(alpha, beta, n)
    s2 = shift(s1, k, n)
    o = {
       "params": {
        "alpha": alpha,
        "beta": beta,
        "k": k,
        "generator": "weibull"
      },
       "s1": s1,
       "s2": s2
    }
    data.append(o)
  return data

m = [100, 200, 300]

final_results_unbiased = []
final_results_unbiased_coordinated = []
final_results_agms = []
final_results_threshold = []
final_results_priority = []

q = 100
n = 40000
data = get_weibull_shifted(n)
for t in range(q):
  iteration_result_unbiased = {}
  iteration_result_unbiased_coordinated = {}
  iteration_result_agms = {}
  iteration_result_threshold = {}
  iteration_result_priority = {}
  print(t)
  for d in data:
    streaming1 = d.get("s1")
    streaming2 = d.get("s1")
    for size in m:
      t1 = time.time()
      sketch1 = unbiased_space_saving(streaming1, n, size)
      sketch2 = unbiased_space_saving(streaming2, n, size)
      t2 = time.time()
      answer1 = get_answer(streaming1, n)
      answer2 = get_answer(streaming2, n)
      v = get_inner_vector(sketch1, sketch2)
      v_ans = get_inner_vector(answer1, answer1)
      ans = calculate_inner_product(v_ans)
      est = calculate_inner_product(v)

      params = list(d.get("params").values())
      params.append(size)
      key = ""
      for p in params:
        key+=f"{p}-"
      key = key[:len(key)-1]
      iteration_result_unbiased[key] = {
          "relative_error": abs(ans - est)/ans,
          "absolute_error": abs(ans - est),
          "duration": t2 - t1
      }

      t1 = time.time()
      est = fast_agms(streaming1, streaming2, size, 4)
      t2 = time.time()
      iteration_result_agms[key] = {
          "relative_error": abs(ans - est)/ans,
          "absolute_error": abs(ans - est),
          "duration": t2 - t1
      }

      t1 = time.time()
      sketch11 = unbiased_space_saving_coordinated(streaming1, n, size)
      sketch22 = unbiased_space_saving_coordinated(streaming2, n, size)
      t2 = time.time()
      v = get_inner_vector(sketch11, sketch22)
      v_ans = get_inner_vector(answer1, answer1)
      ans = calculate_inner_product(v_ans)
      est = calculate_inner_product(v)

      iteration_result_unbiased_coordinated[key] = {
          "relative_error": abs(ans - est)/ans,
          "absolute_error": abs(ans - est),
          "duration": t2 - t1
      }

      t1 = time.time()
      ag1 = get_answer(streaming1, n)
      ag2 = get_answer(streaming2, n)
      sketch111 = threshold_sampling_Chris(ag1, size)
      sketch222 = threshold_sampling_Chris(ag2, size)
      t2 = time.time()
      est = inner_product_from_threshold(sketch111, sketch222)

      iteration_result_threshold[key] = {
          "relative_error": abs(ans - est)/ans,
          "absolute_error": abs(ans - est),
          "duration": t2 - t1
      }

      t1 = time.time()
      sketch1111 = Priority_Sampling_Chris(ag1, size)
      sketch2222 = Priority_Sampling_Chris(ag2, size)
      t2 = time.time()
      est = inner_product_from_threshold(sketch1111, sketch2222)

      iteration_result_priority[key] = {
          "relative_error": abs(ans - est)/ans,
          "absolute_error": abs(ans - est),
          "duration": t2 - t1
      }
  final_results_unbiased.append(iteration_result_unbiased)
  final_results_unbiased_coordinated.append(iteration_result_unbiased_coordinated)
  final_results_agms.append(iteration_result_agms)
  final_results_threshold.append(iteration_result_threshold)
  final_results_priority.append(iteration_result_priority)

# %%
keys = list(final_results_unbiased[0].keys())
print("Unbiased Space Saving")
mean_final_results_unbiased = []
for k in keys:
  absolute_error = 0
  relative_error = 0
  duration = 0
  for result in final_results_unbiased:
      absolute_error += result.get(k).get("absolute_error")
      relative_error += result.get(k).get("relative_error")
      duration += result.get(k).get("duration")
  mean_final_results_unbiased.append([k, absolute_error/q, relative_error/q, duration/q])

  print(f"distribution: {k}")
  print(f"{q} iteractions")
  print(f"Mean Absolute Error: {absolute_error/q}")
  print(f"Mean Relative Error: {relative_error/q}")
  print(f"Mean Duration: {round(duration/q, 2)} seconds")
  print("-------------------------------------------")
# Out:
# Unbiased Space Saving
# distribution: 500000-0.15-1-weibull-100
# 100 iteractions
# Mean Absolute Error: 339809.0
# Mean Relative Error: 0.013728483958986262
# Mean Duration: 0.05 seconds
# -------------------------------------------
# distribution: 500000-0.15-1-weibull-200
# 100 iteractions
# Mean Absolute Error: 283550.64
# Mean Relative Error: 0.011455613043799006
# Mean Duration: 0.05 seconds
# -------------------------------------------
# distribution: 500000-0.15-1-weibull-300
# 100 iteractions
# Mean Absolute Error: 263239.0
# Mean Relative Error: 0.010635010811601788
# Mean Duration: 0.05 seconds
# -------------------------------------------
# distribution: 500000-0.15-2-weibull-100
# 100 iteractions
# Mean Absolute Error: 412781.0
# Mean Relative Error: 0.018235730281841618
# Mean Duration: 0.05 seconds
# -------------------------------------------
# distribution: 500000-0.15-2-weibull-200
# 100 iteractions
# Mean Absolute Error: 341545.0
# Mean Relative Error: 0.01508868503906813
# Mean Duration: 0.05 seconds
# -------------------------------------------
# distribution: 500000-0.15-2-weibull-300
# 100 iteractions
# Mean Absolute Error: 129281.0
# Mean Relative Error: 0.00571134196236445
# Mean Duration: 0.05 seconds
# -------------------------------------------
# distribution: 500000-0.15-3-weibull-100
# 100 iteractions
# Mean Absolute Error: 22393020.0
# Mean Relative Error: 0.9642653310644238
# Mean Duration: 0.05 seconds
# -------------------------------------------
# distribution: 500000-0.15-3-weibull
# Mean Duration: 0.06 seconds
# -------------------------------------------
# distribution: 500000-0.15-16-weibull-200
# 100 iteractions
# Mean Absolute Error: 47857.41427104887
# Mean Relative Error: 0.0019785593883518676
# Mean Duration: 0.06 seconds
# -------------------------------------------
# distribution: 500000-0.15-16-weibull-300
# 100 iteractions
# Mean Absolute Error: 43103.79640838731
# Mean Relative Error: 0.0017820315275372933
# Mean Duration: 0.06 seconds
# -------------------------------------------
# distribution: 500000-0.15-17-weibull-100
# 100 iteractions
# Mean Absolute Error: 59982.56950740903
# Mean Relative Error: 0.0024631686040768185
# Mean Duration: 0.06 seconds
# -------------------------------------------
# distribution: 500000-0.15-17-weibull-200
# 100 iteractions
# Mean Absolute Error: 47799.90265955444
# Mean Relative Error: 0.00196289056097204
# Mean Duration: 0.06 seconds
# -------------------------------------------
# distribution: 500000-0.15-17-weibull-300
# 100 iteractions
# Mean Absolute Error: 43015.21394543912
# Mean Relative Error: 0.0017664085643241004
# Mean Duration: 0.06 seconds
# -------------------------------------------
# distribution: 500000-0.15-18-weibull-100
# 100 iteractions
# Mean Absolute Error: 61489.80181546859
# Mean Relative Error: 0.002633038310572628
# Mean Duration: 0.06 seconds
# -------------------------------------------
# distribution: 500000-0.15-18-weibull-200
# 100 iteractions
# Mean Absolute Error: 48558.78961980078
# Mean Relative Error: 0.002079322905734389
# Mean Duration: 0.06 seconds
# -------------------------------------------
# distribution: 500000-0.15-18-weibull-300
# 100 iteractions
# Mean Absolute Error: 43374.42386473078
# Mean Relative Error: 0.0018573245703016978
# Mean Duration: 0.06 seconds
# -------------------------------------------
# distribution: 500000-0.15-19-weibull-100
# 100 iteractions
# Mean Absolute Error: 62476.257990123035
# Mean Relative Error: 0.0026700508421345155
# Mean Duration: 0.06 seconds
# -------------------------------------------
# distribution: 500000-0.15-19-weibull-200
# 100 iteractions
# Mean Absolute Error: 48436.29145987395
# Mean Relative Error: 0.002070024117365591
# Mean Duration: 0.06 seconds
# -------------------------------------------
# distribution: 500000-0.15-19-weibull-300
# 100 iteractions
# Mean Absolute Error: 42910.164892203844
# Mean Relative Error: 0.0018338537804980682
# Mean Duration: 0.06 seconds
# -------------------------------------------

# %%
import pandas as pd
methods = ["Priority Sampling", "Threshold Sampling", "Unbiased Space Saving", "Unbiased Space Saving Coordinated", "Fast AGMS"]
datas = [mean_final_results_priority, mean_final_results_threshold, mean_final_results_unbiased, mean_final_results_unbiased_coordinated, mean_final_results_agms]
datasets = [d[0] for d in mean_final_results_priority]

di = {}
for i in range(len(methods)):
  di[methods[i]] = [d[2] for d in datas[i]]

di_duration = {}
for i in range(len(methods)):
  di_duration[methods[i]] = [d[3] for d in datas[i]]

df = pd.DataFrame(di, index=datasets)
df_2 = pd.DataFrame(di_duration, index=datasets)

df.to_csv("relative_errors_weibull_shifted.csv")
df_2.to_csv("durations_weibull_shifted.csv")

# %%
def get_weibull_sorted(n):
  data = []
  # Weibull:
  alpha = 500000
  beta = 0.15
  s1 = generate_weibull(alpha, beta, n)
  s1.sort()
  s2 = generate_weibull(alpha, beta, n)
  s2.sort()
  o = {
      "params": {
      "alpha": alpha,
      "beta": beta,
      "generator": "weibull"
    },
      "s1": s1,
      "s2": s2
  }
  data.append(o)
  return data

m = [100, 200, 300]

final_results_unbiased = []
final_results_unbiased_coordinated = []
final_results_agms = []
final_results_threshold = []
final_results_priority = []

q = 100
n = 40000
data = get_weibull_sorted(n)
for t in range(q):
  iteration_result_unbiased = {}
  iteration_result_unbiased_coordinated = {}
  iteration_result_agms = {}
  iteration_result_threshold = {}
  iteration_result_priority = {}
  print(t)
  for d in data:
    streaming1 = d.get("s1")
    streaming2 = d.get("s1")
    for size in m:
      t1 = time.time()
      sketch1 = unbiased_space_saving(streaming1, n, size)
      sketch2 = unbiased_space_saving(streaming2, n, size)
      t2 = time.time()
      answer1 = get_answer(streaming1, n)
      answer2 = get_answer(streaming2, n)
      v = get_inner_vector(sketch1, sketch2)
      v_ans = get_inner_vector(answer1, answer1)
      ans = calculate_inner_product(v_ans)
      est = calculate_inner_product(v)

      params = list(d.get("params").values())
      params.append(size)
      key = ""
      for p in params:
        key+=f"{p}-"
      key = key[:len(key)-1]
      iteration_result_unbiased[key] = {
          "relative_error": abs(ans - est)/ans,
          "absolute_error": abs(ans - est),
          "duration": t2 - t1
      }

      t1 = time.time()
      est = fast_agms(streaming1, streaming2, size, 4)
      t2 = time.time()
      iteration_result_agms[key] = {
          "relative_error": abs(ans - est)/ans,
          "absolute_error": abs(ans - est),
          "duration": t2 - t1
      }

      t1 = time.time()
      sketch11 = unbiased_space_saving_coordinated(streaming1, n, size)
      sketch22 = unbiased_space_saving_coordinated(streaming2, n, size)
      t2 = time.time()
      v = get_inner_vector(sketch11, sketch22)
      v_ans = get_inner_vector(answer1, answer1)
      ans = calculate_inner_product(v_ans)
      est = calculate_inner_product(v)

      iteration_result_unbiased_coordinated[key] = {
          "relative_error": abs(ans - est)/ans,
          "absolute_error": abs(ans - est),
          "duration": t2 - t1
      }

      t1 = time.time()
      ag1 = get_answer(streaming1, n)
      ag2 = get_answer(streaming2, n)
      sketch111 = threshold_sampling_Chris(ag1, size)
      sketch222 = threshold_sampling_Chris(ag2, size)
      t2 = time.time()
      est = inner_product_from_threshold(sketch111, sketch222)

      iteration_result_threshold[key] = {
          "relative_error": abs(ans - est)/ans,
          "absolute_error": abs(ans - est),
          "duration": t2 - t1
      }

      t1 = time.time()
      sketch1111 = Priority_Sampling_Chris(ag1, size)
      sketch2222 = Priority_Sampling_Chris(ag2, size)
      t2 = time.time()
      est = inner_product_from_threshold(sketch1111, sketch2222)

      iteration_result_priority[key] = {
          "relative_error": abs(ans - est)/ans,
          "absolute_error": abs(ans - est),
          "duration": t2 - t1
      }
  final_results_unbiased.append(iteration_result_unbiased)
  final_results_unbiased_coordinated.append(iteration_result_unbiased_coordinated)
  final_results_agms.append(iteration_result_agms)
  final_results_threshold.append(iteration_result_threshold)
  final_results_priority.append(iteration_result_priority)

# %%
keys = list(final_results_unbiased[0].keys())
print("Unbiased Space Saving")
mean_final_results_unbiased = []
for k in keys:
  absolute_error = 0
  relative_error = 0
  duration = 0
  for result in final_results_unbiased:
      absolute_error += result.get(k).get("absolute_error")
      relative_error += result.get(k).get("relative_error")
      duration += result.get(k).get("duration")
  mean_final_results_unbiased.append([k, absolute_error/q, relative_error/q, duration/q])

  print(f"distribution: {k}")
  print(f"{q} iteractions")
  print(f"Mean Absolute Error: {absolute_error/q}")
  print(f"Mean Relative Error: {relative_error/q}")
  print(f"Mean Duration: {round(duration/q, 2)} seconds")
  print("-------------------------------------------")
# Out:
# Unbiased Space Saving
# distribution: 500000-0.15-weibull-100
# 100 iteractions
# Mean Absolute Error: 23079634.0
# Mean Relative Error: 0.9525340779835679
# Mean Duration: 0.05 seconds
# -------------------------------------------
# distribution: 500000-0.15-weibull-200
# 100 iteractions
# Mean Absolute Error: 23070692.0
# Mean Relative Error: 0.9521650270824434
# Mean Duration: 0.05 seconds
# -------------------------------------------
# distribution: 500000-0.15-weibull-300
# 100 iteractions
# Mean Absolute Error: 23067463.0
# Mean Relative Error: 0.9520317609943484
# Mean Duration: 0.05 seconds
# -------------------------------------------

# %%
keys = list(final_results_unbiased_coordinated[0].keys())
print("Unbiased Space Saving Coordinated")
mean_final_results_unbiased_coordinated = []
for k in keys:
  absolute_error = 0
  relative_error = 0
  duration = 0
  for result in final_results_unbiased_coordinated:
      absolute_error += result.get(k).get("absolute_error")
      relative_error += result.get(k).get("relative_error")
      duration += result.get(k).get("duration")
  mean_final_results_unbiased_coordinated.append([k, absolute_error/q, relative_error/q, duration/q])

  print(f"distribution: {k}")
  print(f"{q} iteractions")
  print(f"Mean Absolute Error: {absolute_error/q}")
  print(f"Mean Relative Error: {relative_error/q}")
  print(f"Mean Duration: {round(duration/q, 2)} seconds")
  print("-------------------------------------------")
# Out:
# Unbiased Space Saving Coordinated
# distribution: 500000-0.15-weibull-100
# 100 iteractions
# Mean Absolute Error: 23079634.0
# Mean Relative Error: 0.9525340779835679
# Mean Duration: 0.09 seconds
# -------------------------------------------
# distribution: 500000-0.15-weibull-200
# 100 iteractions
# Mean Absolute Error: 23070692.0
# Mean Relative Error: 0.9521650270824434
# Mean Duration: 0.09 seconds
# -------------------------------------------
# distribution: 500000-0.15-weibull-300
# 100 iteractions
# Mean Absolute Error: 23067463.0
# Mean Relative Error: 0.9520317609943484
# Mean Duration: 0.08 seconds
# -------------------------------------------

# %%
keys = list(final_results_agms[0].keys())
print("Fast AGMS")
mean_final_results_agms = []
for k in keys:
  absolute_error = 0
  relative_error = 0
  duration = 0
  for result in final_results_agms:
      absolute_error += result.get(k).get("absolute_error")
      relative_error += result.get(k).get("relative_error")
      duration += result.get(k).get("duration")
  mean_final_results_agms.append([k, absolute_error/q, relative_error/q, duration/q])

  print(f"distribution: {k}")
  print(f"{q} iteractions")
  print(f"Mean Absolute Error: {absolute_error/q}")
  print(f"Mean Relative Error: {relative_error/q}")
  print(f"Mean Duration: {round(duration/q, 2)} seconds")
  print("-------------------------------------------")
# Out:
# Fast AGMS
# distribution: 500000-0.15-weibull-100
# 100 iteractions
# Mean Absolute Error: 542388.16
# Mean Relative Error: 0.02238524258637739
# Mean Duration: 0.12 seconds
# -------------------------------------------
# distribution: 500000-0.15-weibull-200
# 100 iteractions
# Mean Absolute Error: 397794.02
# Mean Relative Error: 0.016417606971933646
# Mean Duration: 0.12 seconds
# -------------------------------------------
# distribution: 500000-0.15-weibull-300
# 100 iteractions
# Mean Absolute Error: 112244.6
# Mean Relative Error: 0.004632517420754347
# Mean Duration: 0.11 seconds
# -------------------------------------------

# %%
keys = list(final_results_threshold[0].keys())
print("Threshold Sampling")
mean_final_results_threshold = []
for k in keys:
  absolute_error = 0
  relative_error = 0
  duration = 0
  for result in final_results_threshold:
      absolute_error += result.get(k).get("absolute_error")
      relative_error += result.get(k).get("relative_error")
      duration += result.get(k).get("duration")
  mean_final_results_threshold.append([k, absolute_error/q, relative_error/q, duration/q])

  print(f"distribution: {k}")
  print(f"{q} iteractions")
  print(f"Mean Absolute Error: {absolute_error/q}")
  print(f"Mean Relative Error: {relative_error/q}")
  print(f"Mean Duration: {round(duration/q, 2)} seconds")
  print("-------------------------------------------")
# Out:
# Threshold Sampling
# distribution: 500000-0.15-weibull-100
# 100 iteractions
# Mean Absolute Error: 374271.7640000002
# Mean Relative Error: 0.015446805163245831
# Mean Duration: 0.08 seconds
# -------------------------------------------
# distribution: 500000-0.15-weibull-200
# 100 iteractions
# Mean Absolute Error: 286554.3539999991
# Mean Relative Error: 0.011826564813790635
# Mean Duration: 0.08 seconds
# -------------------------------------------
# distribution: 500000-0.15-weibull-300
# 100 iteractions
# Mean Absolute Error: 249805.94533333197
# Mean Relative Error: 0.010309898147123955
# Mean Duration: 0.07 seconds
# -------------------------------------------

# %%
keys = list(final_results_priority[0].keys())
print("Priority Sampling")
mean_final_results_priority = []
for k in keys:
  absolute_error = 0
  relative_error = 0
  duration = 0
  for result in final_results_priority:
      absolute_error += result.get(k).get("absolute_error")
      relative_error += result.get(k).get("relative_error")
      duration += result.get(k).get("duration")
  mean_final_results_priority.append([k, absolute_error/q, relative_error/q, duration/q])

  print(f"distribution: {k}")
  print(f"{q} iteractions")
  print(f"Mean Absolute Error: {absolute_error/q}")
  print(f"Mean Relative Error: {relative_error/q}")
  print(f"Mean Duration: {round(duration/q, 2)} seconds")
  print("-------------------------------------------")
# Out:
# Priority Sampling
# distribution: 500000-0.15-weibull-100
# 100 iteractions
# Mean Absolute Error: 60337.12377492651
# Mean Relative Error: 0.002490211350974196
# Mean Duration: 0.06 seconds
# -------------------------------------------
# distribution: 500000-0.15-weibull-200
# 100 iteractions
# Mean Absolute Error: 48417.19288244799
# Mean Relative Error: 0.0019982563926635544
# Mean Duration: 0.06 seconds
# -------------------------------------------
# distribution: 500000-0.15-weibull-300
# 100 iteractions
# Mean Absolute Error: 43165.18692641869
# Mean Relative Error: 0.0017814975545082114
# Mean Duration: 0.06 seconds
# -------------------------------------------

# %%
import pandas as pd
methods = ["Priority Sampling", "Threshold Sampling", "Unbiased Space Saving", "Unbiased Space Saving Coordinated", "Fast AGMS"]
datas = [mean_final_results_priority, mean_final_results_threshold, mean_final_results_unbiased, mean_final_results_unbiased_coordinated, mean_final_results_agms]
datasets = [d[0] for d in mean_final_results_priority]

di = {}
for i in range(len(methods)):
  di[methods[i]] = [d[2] for d in datas[i]]

di_duration = {}
for i in range(len(methods)):
  di_duration[methods[i]] = [d[3] for d in datas[i]]

df = pd.DataFrame(di, index=datasets)
df_2 = pd.DataFrame(di_duration, index=datasets)

df.to_csv("relative_errors_weibull_sorted.csv")
df_2.to_csv("durations_weibull_sorted.csv")

# %%
import matplotlib.pyplot as plt
import seaborn as sns

n = 40000
alpha = 5000000
streaming0 = generate_weibull(alpha, 0.15, n)
streaming1 = generate_weibull(alpha, 0.32, n)
streaming2 = generate_geometric(0.03, n)
streaming3 = generate_truncated_weibull(alpha, 0.15, 1, 1000, n)
streaming4 = generate_truncated_weibull(alpha, 0.32, 1, 1000, n)
streaming5 = generate_zipf(1.1, n)
streaming6 = generate_zipf(2, n)
streaming7 = generate_zipf(3, n)
streaming8 = generate_zipf(4, n)



def generate_histogram(streaming, name1, name2, title):
  plt.hist(streaming, bins = 1800, range=[1,1000],
          color = 'darkblue')

  # Plot formatting
  plt.legend()
  plt.xlabel('Items')
  plt.ylabel('Frequency')
  plt.title(title)
  plt.savefig(name1, bbox_inches='tight')


  # Density Plot and Histogram of streamings
  p = sns.distplot(streaming, hist=True, kde=True,
              bins=1800, color = 'darkblue',
              hist_kws={'edgecolor':'black'},
              kde_kws={'linewidth': 4})
  fig = p.get_figure()
  fig.savefig(name2)

generate_histogram(streaming0, "weibull-0.15.png", 'weibull-0.15-hist.png', 'Weibull (500k, 0.15)')
generate_histogram(streaming1, "weibull-0.32.png", 'weibull-0.32-hist.png', 'Weibull (500k, 0.32)')
generate_histogram(streaming2, "geometric-0.03.png", 'geometric-0.03-hist.png', 'Geometric (0.03)')
generate_histogram(streaming3, "weibull-truncated-0.15.png", 'weibull-truncated-0.15-hist.png', 'Weibull Truncated (500k, 0.15)')
generate_histogram(streaming4, "weibull-truncated-0.32.png", 'weibull-truncated-0.32-hist.png', 'Weibull Truncated (500k, 0.32)')
generate_histogram(streaming5, "zipfian-1.1.png", 'zipfian-1.1-hist.png', 'Zipfian (1.1)')
generate_histogram(streaming6, "zipfian-2.png", 'zipfian-2-hist.png', 'Zipfian (2)')
generate_histogram(streaming7, "zipfian-3.png", 'zipfian-3-hist.png', 'Zipfian (3)')
generate_histogram(streaming8, "zipfian-4.png", 'zipfian-4-hist.png', 'Zipfian (4)')

# %%
m = [100, 200, 300]

final_results_unbiased_coordinated = []

q = 100
n = 40000
data = get_streamings(n)
for t in range(q):
  iteration_result_unbiased_coordinated = {}
  print(t)
  for d in data:
    streaming1 = d.get("s1")
    streaming2 = d.get("s1")
    for size in m:
      params = list(d.get("params").values())
      params.append(size)
      key = ""
      for p in params:
        key+=f"{p}-"
      key = key[:len(key)-1]

      t1 = time.time()
      sketch11 = unbiased_space_saving_coordinated(streaming1, n, size)
      sketch22 = unbiased_space_saving_coordinated(streaming2, n, size)
      t2 = time.time()
      answer1 = get_answer(streaming1, n)
      answer2 = get_answer(streaming2, n)
      v = get_inner_vector(sketch11, sketch22)
      v_ans = get_inner_vector(answer1, answer1)
      ans = calculate_inner_product(v_ans)
      est = calculate_inner_product(v)

      iteration_result_unbiased_coordinated[key] = {
          "relative_error": abs(ans - est)/ans,
          "absolute_error": abs(ans - est),
          "duration": t2 - t1
      }

  final_results_unbiased_coordinated.append(iteration_result_unbiased_coordinated)

# %%
keys = list(final_results_unbiased_coordinated[0].keys())
print("Unbiased Space Saving Coordinated")
mean_final_results_unbiased_coordinated = []
for k in keys:
  absolute_error = 0
  relative_error = 0
  duration = 0
  for result in final_results_unbiased_coordinated:
    absolute_error += result.get(k).get("absolute_error")
    relative_error += result.get(k).get("relative_error")
    duration += result.get(k).get("duration")
  mean_final_results_unbiased_coordinated.append([k, absolute_error/q, relative_error/q, duration/q])

  print(f"distribution: {k}")
  print(f"{q} iteractions")
  print(f"Mean Absolute Error: {absolute_error/q}")
  print(f"Mean Relative Error: {relative_error/q}")
  print(f"Mean Duration: {round(duration/q, 2)} seconds")
  print("-------------------------------------------")
# Out:
# Unbiased Space Saving Coordinated
# distribution: 500000-0.32-weibull-100
# 100 iteractions
# Mean Absolute Error: 87297.0
# Mean Relative Error: 0.22703676925717647
# Mean Duration: 0.08 seconds
# -------------------------------------------
# distribution: 500000-0.32-weibull-200
# 100 iteractions
# Mean Absolute Error: 24632.0
# Mean Relative Error: 0.06406141906758293
# Mean Duration: 0.08 seconds
# -------------------------------------------
# distribution: 500000-0.32-weibull-300
# 100 iteractions
# Mean Absolute Error: 21276.0
# Mean Relative Error: 0.05533333680098626
# Mean Duration: 0.09 seconds
# -------------------------------------------
# distribution: 500000-0.32-1-1000-truncated_weibull-100
# 100 iteractions
# Mean Absolute Error: 2282556.0
# Mean Relative Error: 0.3600561815831177
# Mean Duration: 0.08 seconds
# -------------------------------------------
# distribution: 500000-0.32-1-1000-truncated_weibull-200
# 100 iteractions
# Mean Absolute Error: 1294864.0
# Mean Relative Error: 0.2042551365703364
# Mean Duration: 0.08 seconds
# -------------------------------------------
# distribution: 500000-0.32-1-1000-truncated_weibull-300
# 100 iteractions
# Mean Absolute Error: 757568.0
# Mean Relative Error: 0.11950070069236332
# Mean Duration: 0.08 seconds
# -------------------------------------------
# distribution: 500000-0.15-weibull-100
# 100 iteractions
# Mean Absolute Error: 253175.0
# Mean Relative Error: 0.011030416719928977
# Mean Duration: 0.09 seconds
# -------------------------------------------
# distribution: 500000-0.15-weibull-200
# 100 iteractions
# Mean Absolute Error: 146618.0
# Mean Relative Error: 0.006387904171590972
# Mean Duration: 0.09 seconds
# -------------------------------------------
# distribution: 500000-0.15-weibull-300
# 100 iteractions
# Mean Absolute Error: 108523.0
# Mean Relative Error: 0.004728167922175782
# Mean Duration: 0.08 seconds
# -------------------------------------------
# distribution: 500000-0.15-1-1000-truncated_weibull-100
# 100 iteractions
# Mean Absolute Error: 1616155.0
# Mean Relative Error: 0.10110910302554997
# Mean Duration: 0.08 seconds
# -------------------------------------------
# distribution: 500000-0.15-1-1000-truncated_weibull-200
# 100 iteractions
# Mean Absolute Error: 670207.0
# Mean Relative Error: 0.04192916435084805
# Mean Duration: 0.08 seconds
# -------------------------------------------
# distribution: 500000-0.15-1-1000-truncated_weibull-300
# 100 iteractions
# Mean Absolute Error: 412186.0
# Mean Relative Error: 0.02578698004813235
# Mean Duration: 0.07 seconds
# -------------------------------------------
# distribution: 0.03-geometric-100
# 100 iteractions
# Mean Absolute Error: 212724.0
# Mean Relative Error: 0.008701237154238458
# Mean Duration: 0.05 seconds
# -------------------------------------------
# distribution: 0.03-geometric-200
# 100 iteractions
# Mean Absolute Error: 27260.0
# Mean Relative Error: 0.0011150397925224248
# Mean Duration: 0.05 seconds
# -------------------------------------------
# distribution: 0.03-geometric-300
# 100 iteractions
# Mean Absolute Error: 0.0
# Mean Relative Error: 0.0
# Mean Duration: 0.05 seconds
# -------------------------------------------
# distribution: 1.1-zipfian-100
# 100 iteractions
# Mean Absolute Error: 807914.0
# Mean Relative Error: 0.03718182568758944
# Mean Duration: 0.06 seconds
# -------------------------------------------
# distribution: 1.1-zipfian-200
# 100 iteractions
# Mean Absolute Error: 382419.0
# Mean Relative Error: 0.017599690805732145
# Mean Duration: 0.06 seconds
# -------------------------------------------
# distribution: 1.1-zipfian-300
# 100 iteractions
# Mean Absolute Error: 220158.0
# Mean Relative Error: 0.010132113541451606
# Mean Duration: 0.06 seconds
# -------------------------------------------
# distribution: 2-zipfian-100
# 100 iteractions
# Mean Absolute Error: 574130780.0
# Mean Relative Error: 0.9074715806787439
# Mean Duration: 0.06 seconds
# -------------------------------------------
# distribution: 2-zipfian-200
# 100 iteractions
# Mean Absolute Error: 344055558.0
# Mean Relative Error: 0.5438144965151771
# Mean Duration: 0.05 seconds
# -------------------------------------------
# distribution: 2-zipfian-300
# 100 iteractions
# Mean Absolute Error: 0.0
# Mean Relative Error: 0.0
# Mean Duration: 0.05 seconds
# -------------------------------------------
# distribution: 3-zipfian-100
# 100 iteractions
# Mean Absolute Error: 0.0
# Mean Relative Error: 0.0
# Mean Duration: 0.05 seconds
# -------------------------------------------
# distribution: 3-zipfian-200
# 100 iteractions
# Mean Absolute Error: 0.0
# Mean Relative Error: 0.0
# Mean Duration: 0.05 seconds
# -------------------------------------------
# distribution: 3-zipfian-300
# 100 iteractions
# Mean Absolute Error: 0.0
# Mean Relative Error: 0.0
# Mean Duration: 0.05 seconds
# -------------------------------------------
# distribution: 4-zipfian-100
# 100 iteractions
# Mean Absolute Error: 0.0
# Mean Relative Error: 0.0
# Mean Duration: 0.05 seconds
# -------------------------------------------
# distribution: 4-zipfian-200
# 100 iteractions
# Mean Absolute Error: 0.0
# Mean Relative Error: 0.0
# Mean Duration: 0.05 seconds
# -------------------------------------------
# distribution: 4-zipfian-300
# 100 iteractions
# Mean Absolute Error: 0.0
# Mean Relative Error: 0.0
# Mean Duration: 0.05 seconds
# -------------------------------------------

# %%
import pandas as pd
methods = ["Unbiased Space Saving Coordinated"]
datas = [mean_final_results_unbiased_coordinated]
datasets = [d[0] for d in mean_final_results_unbiased_coordinated]

di = {}
for i in range(len(methods)):
  di[methods[i]] = [d[2] for d in datas[i]]

di_duration = {}
for i in range(len(methods)):
  di_duration[methods[i]] = [d[3] for d in datas[i]]

df = pd.DataFrame(di, index=datasets)
df_2 = pd.DataFrame(di_duration, index=datasets)

df.to_csv("relative_errors_unbiased_first.csv")
df_2.to_csv("durations_unbiased_first.csv")

# %%
m = [100, 200, 300]

final_results_unbiased_coordinated = []

q = 100
n = 40000
data = get_weibull_multiple_params(n)
for t in range(q):
  iteration_result_unbiased_coordinated = {}
  print(t)
  for d in data:
    streaming1 = d.get("s1")
    streaming2 = d.get("s1")
    for size in m:
      params = list(d.get("params").values())
      params.append(size)
      key = ""
      for p in params:
        key+=f"{p}-"
      key = key[:len(key)-1]

      t1 = time.time()
      sketch11 = unbiased_space_saving_coordinated(streaming1, n, size)
      sketch22 = unbiased_space_saving_coordinated(streaming2, n, size)
      t2 = time.time()
      answer1 = get_answer(streaming1, n)
      answer2 = get_answer(streaming2, n)
      v = get_inner_vector(sketch11, sketch22)
      v_ans = get_inner_vector(answer1, answer1)
      ans = calculate_inner_product(v_ans)
      est = calculate_inner_product(v)

      iteration_result_unbiased_coordinated[key] = {
          "relative_error": abs(ans - est)/ans,
          "absolute_error": abs(ans - est),
          "duration": t2 - t1
      }

  final_results_unbiased_coordinated.append(iteration_result_unbiased_coordinated)

# %%
keys = list(final_results_unbiased_coordinated[0].keys())
print("Unbiased Space Saving Coordinated")
mean_final_results_unbiased_coordinated = []
for k in keys:
  absolute_error = 0
  relative_error = 0
  duration = 0
  for result in final_results_unbiased_coordinated:
    absolute_error += result.get(k).get("absolute_error")
    relative_error += result.get(k).get("relative_error")
    duration += result.get(k).get("duration")
  mean_final_results_unbiased_coordinated.append([k, absolute_error/q, relative_error/q, duration/q])

  print(f"distribution: {k}")
  print(f"{q} iteractions")
  print(f"Mean Absolute Error: {absolute_error/q}")
  print(f"Mean Relative Error: {relative_error/q}")
  print(f"Mean Duration: {round(duration/q, 2)} seconds")
  print("-------------------------------------------")
# Out:
# Unbiased Space Saving Coordinated
# distribution: 500000-0.0-weibull-100
# 100 iteractions
# Mean Absolute Error: 0.0
# Mean Relative Error: 0.0
# Mean Duration: 0.07 seconds
# -------------------------------------------
# distribution: 500000-0.0-weibull-200
# 100 iteractions
# Mean Absolute Error: 0.0
# Mean Relative Error: 0.0
# Mean Duration: 0.07 seconds
# -------------------------------------------
# distribution: 500000-0.0-weibull-300
# 100 iteractions
# Mean Absolute Error: 0.0
# Mean Relative Error: 0.0
# Mean Duration: 0.07 seconds
# -------------------------------------------
# distribution: 500000-0.05-weibull-100
# 100 iteractions
# Mean Absolute Error: 247919754.0
# Mean Relative Error: 0.9970774966785754
# Mean Duration: 0.25 seconds
# -------------------------------------------
# distribution: 500000-0.05-weibull-200
# 100 iteractions
# Mean Absolute Error: 247878391.0
# Mean Relative Error: 0.996911143994576
# Mean Duration: 0.25 seconds
# -------------------------------------------
# distribution: 500000-0.05-weibull-300
# 100 iteractions
# Mean Absolute Error: 247830660.0
# Mean Relative Error: 0.9967191806466505
# Mean Duration: 0.26 seconds
# -------------------------------------------
# distribution: 500000-0.1-weibull-100
# 100 iteractions
# Mean Absolute Error: 291093.0
# Mean Relative Error: 0.0036753623715407202
# Mean Duration: 0.1 seconds
# -------------------------------------------
# distribution: 500000-0.1-weibull-200
# 100 iteractions
# Mean Absolute Error: 204954.0
# Mean Relative Error: 0.0025877648019593602
# Mean Duration: 0.1 seconds
# -------------------------------------------
# distribution: 500000-0.1-weibull-300
# 100 iteractions
# Mean Absolute Error: 114299.0
# Mean Relative Error: 0.001443147872689257
# Mean Duration: 0.1 seconds
# -------------------------------------------
# distribution: 500000-0.15-weibull-100
# 100 iteractions
# Mean Absolute Error: 155438.0
# Mean Relative Error: 0.006599211531820515
# Mean Duration: 0.1 seconds
# -------------------------------------------
# distribution: 500000-0.15-weibull-200
# 100 iteractions
# Mean Absolute Error: 149368.0
# Mean Relative Error: 0.006341506118741657
# Mean Duration: 0.1 seconds
# -------------------------------------------
# distribution: 500000-0.15-weibull-300
# 100 iteractions
# Mean Absolute Error: 76616.0
# Mean Relative Error: 0.00325277725345128
# Mean Duration: 0.1 seconds
# -------------------------------------------
# distribution: 500000-0.2-weibull-100
# 100 iteractions
# Mean Absolute Error: 270685.0
# Mean Relative Error: 0.03962325520664087
# Mean Duration: 0.1 seconds
# -------------------------------------------
# distribution: 500000-0.2-weibull-200
# 100 iteractions
# Mean Absolute Error: 242618.0
# Mean Relative Error: 0.03551476783613706
# Mean Duration: 0.1 seconds
# -------------------------------------------
# distribution: 500000-0.2-weibull-300
# 100 iteractions
# Mean Absolute Error: 228731.0
# Mean Relative Error: 0.03348196902920421
# Mean Duration: 0.1 seconds
# -------------------------------------------
# distribution: 500000-0.32-weibull-100
# 100 iteractions
# Mean Absolute Error: 46237.0
# Mean Relative Error: 0.1153992063293981
# Mean Duration: 0.1 seconds
# -------------------------------------------
# distribution: 500000-0.32-weibull-200
# 100 iteractions
# Mean Absolute Error: 16184.0
# Mean Relative Error: 0.04039234282576675
# Mean Duration: 0.1 seconds
# -------------------------------------------
# distribution: 500000-0.32-weibull-300
# 100 iteractions
# Mean Absolute Error: 15134.0
# Mean Relative Error: 0.037771732348316524
# Mean Duration: 0.1 seconds
# -------------------------------------------
# distribution: 500000-0.4-weibull-100
# 100 iteractions
# Mean Absolute Error: 6160.0
# Mean Relative Error: 0.060736329395989046
# Mean Duration: 0.09 seconds
# -------------------------------------------
# distribution: 500000-0.4-weibull-200
# 100 iteractions
# Mean Absolute Error: 6830.0
# Mean Relative Error: 0.06734239119717605
# Mean Duration: 0.09 seconds
# -------------------------------------------
# distribution: 500000-0.4-weibull-300
# 100 iteractions
# Mean Absolute Error: 7363.0
# Mean Relative Error: 0.07259766125692656
# Mean Duration: 0.1 seconds
# -------------------------------------------
# distribution: 500000-0.6-weibull-100
# 100 iteractions
# Mean Absolute Error: 35739.0
# Mean Relative Error: 0.8131370586093907
# Mean Duration: 0.09 seconds
# -------------------------------------------
# distribution: 500000-0.6-weibull-200
# 100 iteractions
# Mean Absolute Error: 35869.0
# Mean Relative Error: 0.8160948307244253
# Mean Duration: 0.1 seconds
# -------------------------------------------
# distribution: 500000-0.6-weibull-300
# 100 iteractions
# Mean Absolute Error: 35415.0
# Mean Relative Error: 0.8057653804149969
# Mean Duration: 0.1 seconds
# -------------------------------------------
# distribution: 500000-0.8-weibull-100
# 100 iteractions
# Mean Absolute Error: 30549.0
# Mean Relative Error: 0.7285714285714279
# Mean Duration: 0.1 seconds
# -------------------------------------------
# distribution: 500000-0.8-weibull-200
# 100 iteractions
# Mean Absolute Error: 30655.0
# Mean Relative Error: 0.7310994514667315
# Mean Duration: 0.1 seconds
# -------------------------------------------
# distribution: 500000-0.8-weibull-300
# 100 iteractions
# Mean Absolute Error: 30244.0
# Mean Relative Error: 0.721297400429287
# Mean Duration: 0.1 seconds
# -------------------------------------------
# distribution: 500000-1-weibull-100
# 100 iteractions
# Mean Absolute Error: 43155.0
# Mean Relative Error: 1.0364330659493717
# Mean Duration: 0.1 seconds
# -------------------------------------------
# distribution: 500000-1-weibull-200
# 100 iteractions
# Mean Absolute Error: 42677.0
# Mean Relative Error: 1.0249531677794306
# Mean Duration: 0.1 seconds
# -------------------------------------------
# distribution: 500000-1-weibull-300
# 100 iteractions
# Mean Absolute Error: 42222.0
# Mean Relative Error: 1.0140256496469566
# Mean Duration: 0.1 seconds
# -------------------------------------------

# %%
import pandas as pd
methods = ["Unbiased Space Saving Coordinated"]
datas = [mean_final_results_unbiased_coordinated]
datasets = [d[0] for d in mean_final_results_unbiased_coordinated]

di = {}
for i in range(len(methods)):
  di[methods[i]] = [d[2] for d in datas[i]]

di_duration = {}
for i in range(len(methods)):
  di_duration[methods[i]] = [d[3] for d in datas[i]]

df = pd.DataFrame(di, index=datasets)
df_2 = pd.DataFrame(di_duration, index=datasets)

df.to_csv("relative_errors_unbiased_weibull_multiple.csv")
df_2.to_csv("durations_unbiased_weibull_multiple.csv")

# %%
m = [100, 200, 300]

final_results_unbiased_coordinated = []

q = 100
n = 40000
data = get_weibull_shifted(n)
for t in range(q):
  iteration_result_unbiased_coordinated = {}
  print(t)
  for d in data:
    streaming1 = d.get("s1")
    streaming2 = d.get("s1")
    for size in m:
      params = list(d.get("params").values())
      params.append(size)
      key = ""
      for p in params:
        key+=f"{p}-"
      key = key[:len(key)-1]

      t1 = time.time()
      sketch11 = unbiased_space_saving_coordinated(streaming1, n, size)
      sketch22 = unbiased_space_saving_coordinated(streaming2, n, size)
      t2 = time.time()
      answer1 = get_answer(streaming1, n)
      answer2 = get_answer(streaming2, n)
      v = get_inner_vector(sketch11, sketch22)
      v_ans = get_inner_vector(answer1, answer1)
      ans = calculate_inner_product(v_ans)
      est = calculate_inner_product(v)

      iteration_result_unbiased_coordinated[key] = {
          "relative_error": abs(ans - est)/ans,
          "absolute_error": abs(ans - est),
          "duration": t2 - t1
      }

  final_results_unbiased_coordinated.append(iteration_result_unbiased_coordinated)

# %%
keys = list(final_results_unbiased_coordinated[0].keys())
print("Unbiased Space Saving Coordinated")
mean_final_results_unbiased_coordinated = []
for k in keys:
  absolute_error = 0
  relative_error = 0
  duration = 0
  for result in final_results_unbiased_coordinated:
    absolute_error += result.get(k).get("absolute_error")
    relative_error += result.get(k).get("relative_error")
    duration += result.get(k).get("duration")
  mean_final_results_unbiased_coordinated.append([k, absolute_error/q, relative_error/q, duration/q])

  print(f"distribution: {k}")
  print(f"{q} iteractions")
  print(f"Mean Absolute Error: {absolute_error/q}")
  print(f"Mean Relative Error: {relative_error/q}")
  print(f"Mean Duration: {round(duration/q, 2)} seconds")
  print("-------------------------------------------")
# Out:
# Unbiased Space Saving Coordinated
# distribution: 500000-0.15-1-weibull-100
# 100 iteractions
# Mean Absolute Error: 206854.0
# Mean Relative Error: 0.00861566999502353
# Mean Duration: 0.08 seconds
# -------------------------------------------
# distribution: 500000-0.15-1-weibull-200
# 100 iteractions
# Mean Absolute Error: 195627.0
# Mean Relative Error: 0.00814805454144696
# Mean Duration: 0.08 seconds
# -------------------------------------------
# distribution: 500000-0.15
# Mean Duration: 0.08 seconds
# -------------------------------------------
# distribution: 500000-0.15-11-weibull-200
# 100 iteractions
# Mean Absolute Error: 142782.0
# Mean Relative Error: 0.00603176963508263
# Mean Duration: 0.08 seconds
# -------------------------------------------
# distribution: 500000-0.15-11-weibull-300
# 100 iteractions
# Mean Absolute Error: 129225.0
# Mean Relative Error: 0.005459059482942895
# Mean Duration: 0.08 seconds
# -------------------------------------------
# distribution: 500000-0.15-12-weibull-100
# 100 iteractions
# Mean Absolute Error: 218725.0
# Mean Relative Error: 0.009306298371690287
# Mean Duration: 0.08 seconds
# -------------------------------------------
# distribution: 500000-0.15-12-weibull-200
# 100 iteractions
# Mean Absolute Error: 180680.0
# Mean Relative Error: 0.007687561960438931
# Mean Duration: 0.08 seconds
# -------------------------------------------
# distribution: 500000-0.15-12-weibull-300
# 100 iteractions
# Mean Absolute Error: 131436.0
# Mean Relative Error: 0.005592331159133554
# Mean Duration: 0.08 seconds
# -------------------------------------------
# distribution: 500000-0.15-13-weibull-100
# 100 iteractions
# Mean Absolute Error: 816359.0
# Mean Relative Error: 0.03435010948910953
# Mean Duration: 0.08 seconds
# -------------------------------------------
# distribution: 500000-0.15-13-weibull-200
# 100 iteractions
# Mean Absolute Error: 179163.0
# Mean Relative Error: 0.007538679265368922
# Mean Duration: 0.08 seconds
# -------------------------------------------
# distribution: 500000-0.15-13-weibull-300
# 100 iteractions
# Mean Absolute Error: 55363.0
# Mean Relative Error: 0.0023295206050837555
# Mean Duration: 0.08 seconds
# -------------------------------------------
# distribution: 500000-0.15-14-weibull-100
# 100 iteractions
# Mean Absolute Error: 23199862.0
# Mean Relative Error: 0.9647617830966386
# Mean Duration: 0.08 seconds
# -------------------------------------------
# distribution: 500000-0.15-14-weibull-200
# 100 iteractions
# Mean Absolute Error: 23165693.0
# Mean Relative Error: 0.9633408718271422
# Mean Duration: 0.09 seconds
# -------------------------------------------
# distribution: 500000-0.15-14-weibull-300
# 100 iteractions
# Mean Absolute Error: 23099940.0
# Mean Relative Error: 0.960606546014172
# Mean Duration: 0.08 seconds
# -------------------------------------------
# distribution: 500000-0.15-15-weibull-100
# 100 iteractions
# Mean Absolute Error: 264222.0
# Mean Relative Error: 0.01056547369128192
# Mean Duration: 0.08 seconds
# -------------------------------------------
# distribution: 500000-0.15-15-weibull-200
# 100 iteractions
# Mean Absolute Error: 251432.0
# Mean Relative Error: 0.010054038577962476
# Mean Duration: 0.08 seconds
# -------------------------------------------
# distribution: 500000-0.15-15-weibull-300
# 100 iteractions
# Mean Absolute Error: 218653.0
# Mean Relative Error: 0.008743301159706117
# Mean Duration: 0.08 seconds
# -------------------------------------------
# distribution: 500000-0.15-16-weibull-100
# 100 iteractions
# Mean Absolute Error: 166147.0
# Mean Relative Error: 0.007249098351207209
# Mean Duration: 0.08 seconds
# -------------------------------------------
# distribution: 500000-0.15-16-weibull-200
# 100 iteractions
# Mean Absolute Error: 110358.0
# Mean Relative Error: 0.004814989111103563
# Mean Duration: 0.08 seconds
# -------------------------------------------
# distribution: 500000-0.15-16-weibull-300
# 100 iteractions
# Mean Absolute Error: 69960.0
# Mean Relative Error: 0.0030523989036844185
# Mean Duration: 0.08 seconds
# -------------------------------------------
# distribution: 500000-0.15-17-weibull-100
# 100 iteractions
# Mean Absolute Error: 419227.0
# Mean Relative Error: 0.017936037330567315
# Mean Duration: 0.08 seconds
# -------------------------------------------
# distribution: 500000-0.15-17-weibull-200
# 100 iteractions
# Mean Absolute Error: 90131.0
# Mean Relative Error: 0.003856128018093703
# Mean Duration: 0.08 seconds
# -------------------------------------------
# distribution: 500000-0.15-17-weibull-300
# 100 iteractions
# Mean Absolute Error: 77968.0
# Mean Relative Error: 0.003335751176784121
# Mean Duration: 0.08 seconds
# -------------------------------------------
# distribution: 500000-0.15-18-weibull-100
# 100 iteractions
# Mean Absolute Error: 277551.0
# Mean Relative Error: 0.011301509840442224
# Mean Duration: 0.08 seconds
# -------------------------------------------
# distribution: 500000-0.15-18-weibull-200
# 100 iteractions
# Mean Absolute Error: 183574.0
# Mean Relative Error: 0.007474890623522687
# Mean Duration: 0.08 seconds
# -------------------------------------------
# distribution: 500000-0.15-18-weibull-300
# 100 iteractions
# Mean Absolute Error: 56915.0
# Mean Relative Error: 0.002317503567159796
# Mean Duration: 0.08 seconds
# -------------------------------------------
# distribution: 500000-0.15-19-weibull-100
# 100 iteractions
# Mean Absolute Error: 1213546.0
# Mean Relative Error: 0.05151979983480327
# Mean Duration: 0.08 seconds
# -------------------------------------------
# distribution: 500000-0.15-19-weibull-200
# 100 iteractions
# Mean Absolute Error: 1058078.0
# Mean Relative Error: 0.04491957187416783
# Mean Duration: 0.08 seconds
# -------------------------------------------
# distribution: 500000-0.15-19-weibull-300
# 100 iteractions
# Mean Absolute Error: 859685.0
# Mean Relative Error: 0.03649700886573957
# Mean Duration: 0.08 seconds
# -------------------------------------------

# %%
import pandas as pd
methods = ["Unbiased Space Saving Coordinated"]
datas = [mean_final_results_unbiased_coordinated]
datasets = [d[0] for d in mean_final_results_unbiased_coordinated]

di = {}
for i in range(len(methods)):
  di[methods[i]] = [d[2] for d in datas[i]]

di_duration = {}
for i in range(len(methods)):
  di_duration[methods[i]] = [d[3] for d in datas[i]]

df = pd.DataFrame(di, index=datasets)
df_2 = pd.DataFrame(di_duration, index=datasets)

df.to_csv("relative_errors_unbiased_weibull_shifted.csv")
df_2.to_csv("durations_unbiased_weibull_shifted.csv")

# %%
m = [100, 200, 300]

final_results_unbiased_coordinated = []

q = 100
n = 40000
data = get_weibull_sorted(n)
for t in range(q):
  iteration_result_unbiased_coordinated = {}
  print(t)
  for d in data:
    streaming1 = d.get("s1")
    streaming2 = d.get("s1")
    for size in m:
      params = list(d.get("params").values())
      params.append(size)
      key = ""
      for p in params:
        key+=f"{p}-"
      key = key[:len(key)-1]

      t1 = time.time()
      sketch11 = unbiased_space_saving_coordinated(streaming1, n, size)
      sketch22 = unbiased_space_saving_coordinated(streaming2, n, size)
      t2 = time.time()
      answer1 = get_answer(streaming1, n)
      answer2 = get_answer(streaming2, n)
      v = get_inner_vector(sketch11, sketch22)
      v_ans = get_inner_vector(answer1, answer1)
      ans = calculate_inner_product(v_ans)
      est = calculate_inner_product(v)

      iteration_result_unbiased_coordinated[key] = {
          "relative_error": abs(ans - est)/ans,
          "absolute_error": abs(ans - est),
          "duration": t2 - t1
      }

  final_results_unbiased_coordinated.append(iteration_result_unbiased_coordinated)

# %%
keys = list(final_results_unbiased_coordinated[0].keys())
print("Unbiased Space Saving Coordinated")
mean_final_results_unbiased_coordinated = []
for k in keys:
  absolute_error = 0
  relative_error = 0
  duration = 0
  for result in final_results_unbiased_coordinated:
    absolute_error += result.get(k).get("absolute_error")
    relative_error += result.get(k).get("relative_error")
    duration += result.get(k).get("duration")
  mean_final_results_unbiased_coordinated.append([k, absolute_error/q, relative_error/q, duration/q])

  print(f"distribution: {k}")
  print(f"{q} iteractions")
  print(f"Mean Absolute Error: {absolute_error/q}")
  print(f"Mean Relative Error: {relative_error/q}")
  print(f"Mean Duration: {round(duration/q, 2)} seconds")
  print("-------------------------------------------")
# Out:
# Unbiased Space Saving Coordinated
# distribution: 500000-0.15-weibull-100
# 100 iteractions
# Mean Absolute Error: 120317.0
# Mean Relative Error: 0.005070494356026523
# Mean Duration: 0.08 seconds
# -------------------------------------------
# distribution: 500000-0.15-weibull-200
# 100 iteractions
# Mean Absolute Error: 101971.0
# Mean Relative Error: 0.004297342686223727
# Mean Duration: 0.08 seconds
# -------------------------------------------
# distribution: 500000-0.15-weibull-300
# 100 iteractions
# Mean Absolute Error: 86389.0
# Mean Relative Error: 0.0036406736946796854
# Mean Duration: 0.08 seconds
# -------------------------------------------

# %%
import pandas as pd
methods = ["Unbiased Space Saving Coordinated"]
datas = [mean_final_results_unbiased_coordinated]
datasets = [d[0] for d in mean_final_results_unbiased_coordinated]

di = {}
for i in range(len(methods)):
  di[methods[i]] = [d[2] for d in datas[i]]

di_duration = {}
for i in range(len(methods)):
  di_duration[methods[i]] = [d[3] for d in datas[i]]

df = pd.DataFrame(di, index=datasets)
df_2 = pd.DataFrame(di_duration, index=datasets)

df.to_csv("relative_errors_unbiased_weibull_sorted.csv")
df_2.to_csv("durations_unbiased_weibull_sorted.csv")
